# %% [markdown]
# # Deliverable for Improvement 1
#
#
# **Group 16**
#
# Sarim Malik (26100129), Muhammad Nafees (26100029)
#
# **Note:** non-IID partitioning framework and evaluation metrics shall be kept constant across all the baseline model development.

# %% [markdown]
# # Knowledge Carrier: Logit Based

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import numpy as np
from torch.utils.data import Dataset, DataLoader, Subset, random_split
import matplotlib.pyplot as plt
from collections import Counter
import copy
import random
from typing import Dict, List, Tuple

# random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(128 * 4 * 4, 512)
        self.fc2 = nn.Linear(512, 10)
        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

    def get_features(self, x):

        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))
        x = x.view(-1, 128 * 4 * 4)
        x = self.dropout(F.relu(self.fc1(x)))
        return x

# %%
def load_and_partition_data():
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    #  seeds for data partitioning
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    full_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

    n_total = len(full_dataset)
    n_server_val = int(0.1 * n_total)  # 10% for server validation
    n_client_data = n_total - n_server_val  # 90% for clients

    g = torch.Generator().manual_seed(42)
    client_data, server_val_data = random_split(full_dataset, [n_client_data, n_server_val], generator=g)

    client_indices = client_data.indices
    all_targets = np.array(full_dataset.targets)
    labels = all_targets[client_indices]

    num_classes = 10
    num_clients = NUM_OF_CLIENTS

    np.random.seed(42)
    client_label_distribution = np.random.dirichlet(np.repeat(ALPHA, num_clients), size=num_classes)

    class_indices = [np.where(labels == class_idx)[0] for class_idx in range(num_classes)]

    client_indices = [[] for _ in range(num_clients)]

    for class_idx, distribution in enumerate(client_label_distribution):
        class_size = len(class_indices[class_idx])
        num_samples_per_client = (distribution * class_size).astype(int)
        samples_assigned = 0

        for client_idx, num_samples in enumerate(num_samples_per_client):
            if client_idx == num_clients - 1:
                num_samples = class_size - samples_assigned

            if num_samples > 0:
                selected_indices = class_indices[class_idx][samples_assigned:samples_assigned+num_samples]
                client_indices[client_idx].extend(selected_indices)
                samples_assigned += num_samples

    client_datasets = []
    client_train_loaders = []
    client_val_loaders = []
    client_class_distributions = []

    for client_idx, indices in enumerate(client_indices):
        np.random.seed(42 + client_idx)
        np.random.shuffle(indices)

        client_labels = [labels[i] for i in indices]
        class_counts = Counter(client_labels)
        distribution = {cls: count/len(client_labels) for cls, count in class_counts.items()}
        client_class_distributions.append(distribution)

        n_train = int(0.8 * len(indices))
        train_indices = indices[:n_train]
        val_indices = indices[n_train:]

        train_indices_original = [client_data.indices[i] for i in train_indices]
        val_indices_original = [client_data.indices[i] for i in val_indices]

        client_train_dataset = Subset(full_dataset, train_indices_original)
        client_val_dataset = Subset(full_dataset, val_indices_original)

        g_train = torch.Generator().manual_seed(42 + client_idx)
        g_val = torch.Generator().manual_seed(42 + client_idx + num_clients)

        train_loader = DataLoader(client_train_dataset, batch_size=BATCH_SIZE,
                                  shuffle=True, generator=g_train)
        val_loader = DataLoader(client_val_dataset, batch_size=BATCH_SIZE,
                                generator=g_val)

        client_datasets.append((client_train_dataset, client_val_dataset))
        client_train_loaders.append(train_loader)
        client_val_loaders.append(val_loader)

    g_server = torch.Generator().manual_seed(42 + 2*num_clients)
    g_test = torch.Generator().manual_seed(42 + 2*num_clients + 1)

    server_val_loader = DataLoader(server_val_data, batch_size=BATCH_SIZE, generator=g_server)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, generator=g_test)

    print("Data partitioning complete.")
    for i, dist in enumerate(client_class_distributions):
        print(f"Client {i} class distribution:")
        for cls in range(10):
            print(f"  Class {cls}: {dist.get(cls, 0):.2f}")

    # reset random seeds
    torch.manual_seed(42)
    np.random.seed(42)
    random.seed(42)

    return client_train_loaders, client_val_loaders, server_val_loader, test_loader, client_class_distributions

# %% [markdown]
# ---

# %%
def temperature_cross_entropy_loss(logits, targets, temperature):
    """Compute cross-entropy loss using softmax with temperature scaling."""
    probs = torch.softmax(logits / temperature, dim=1)
    log_probs = torch.log(probs + 1e-8)
    one_hot = F.one_hot(targets, num_classes=logits.size(1)).float()
    loss = -(one_hot * log_probs).sum(dim=1).mean()
    return loss

def calculate_global_distribution(client_distributions):
    """
    Calculate approximate global class distribution from client distributions
    """
    global_dist = {}
    n_clients = len(client_distributions)

    
    for cls in range(10):
        global_dist[cls] = sum(dist.get(cls, 0) for dist in client_distributions) / n_clients

    
    for cls in range(10):
        if global_dist[cls] < 0.01:
            global_dist[cls] = 0.01

    
    total = sum(global_dist.values())
    global_dist = {k: v/total for k, v in global_dist.items()}

    return global_dist

def calculate_heterogeneity_score(client_distribution, global_distribution):
    """
    Calculate how different client's class distribution is from global distribution
    """
    score = 0
    for cls in range(10):
        client_prob = client_distribution.get(cls, 0)
        global_prob = global_distribution.get(cls, 1/10)  
        if client_prob > 0 and global_prob > 0:
            
            ratio = client_prob / global_prob
            score += abs(ratio - 1)

    # normalize to [0, 1] range approximately
    score = min(score / 10, 1)
    return score


def client_local_train(model, train_loader, optimizer, temperature, epochs=1):
    """Local training on client using modified softmax loss."""
    model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        for inputs, targets in train_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = temperature_cross_entropy_loss(outputs, targets, temperature)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        print(f"Client local training - Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(train_loader):.4f}")

def calculate_client_temperature(client_distribution, global_distribution):
    """
    Calculate a temperature in (0,1) based on heterogeneity.
    A high heterogeneity score (close to 1) yields a temperature close to 0.01.
    A low heterogeneity score (close to 0) yields a temperature close to 0.99.
    """
    score = calculate_heterogeneity_score(client_distribution, global_distribution)
    # map heterogeneity score linearly into (0.01, 0.99)
    client_temp = 0.99 - 0.98 * score
    
    client_temp = min(max(client_temp, 0.01), 0.99) #(0,1)
    return client_temp

def client_predict_logits(model, public_loader):
    """Clients predict and upload local logits for the unlabeled public dataset."""
    model.eval()
    all_logits = []
    with torch.no_grad():
        for inputs, _ in public_loader:
            inputs = inputs.to(device)
            logits = model(inputs)
            all_logits.append(logits.cpu())
    return torch.cat(all_logits, dim=0)


def aggregate_logits(clients_logits):
    """Server side aggregation: simple average of client logits."""
    aggregated = torch.mean(torch.stack(clients_logits), dim=0)
    return aggregated


def server_distillation_update(global_model, public_loader, aggregated_logits, optimizer, temperature, epochs=1):
   
    global_model.train()
    for epoch in range(epochs):
        running_loss = 0.0
        for idx, (inputs, _) in enumerate(public_loader):
            inputs = inputs.to(device)
            batch_size = inputs.size(0)
            
            agg_logits_batch = aggregated_logits[idx*batch_size: idx*batch_size+batch_size].to(device)
            optimizer.zero_grad()
            outputs = global_model(inputs)
            loss = F.kl_div(F.log_softmax(outputs / temperature, dim=1),
                            F.softmax(agg_logits_batch / temperature, dim=1),
                            reduction='batchmean') * (temperature ** 2)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        print(f"Server KD distillation - Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(public_loader):.4f}")


def client_distillation_update(model, public_loader, aggregated_logits, optimizer, temperature, epochs=1):
    
    model.train()
    epoch_accs = []
    for epoch in range(epochs):
        running_loss = 0.0
        for idx, (inputs, _) in enumerate(public_loader):
            inputs = inputs.to(device)
            batch_size = inputs.size(0)
            agg_logits_batch = aggregated_logits[idx*batch_size: idx*batch_size+batch_size].to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = F.kl_div(F.log_softmax(outputs / temperature, dim=1),
                            F.softmax(agg_logits_batch / temperature, dim=1),
                            reduction='batchmean') * (temperature ** 2)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        # evaluate on public data after the epoch
        model.eval()
        acc = evaluate_model(model, public_loader)
        epoch_accs.append(acc)
        print(f"Client distillation update - Epoch [{epoch+1}/{epochs}], Loss: {running_loss/len(public_loader):.4f}, Accuracy: {acc:.2f}%")
        model.train()
    return epoch_accs

def evaluate_model(model, data_loader):
    
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in data_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            _, predicted = torch.max(outputs, 1)
            total += targets.size(0)
            correct += (predicted == targets).sum().item()
    return 100 * correct / total

def plot_accuracies(rounds, server_accuracies, client_accuracies):
    
    plt.figure(figsize=(8, 6))
    plt.plot(rounds, server_accuracies, label='Server Accuracy', marker='o')
    for i, acc in enumerate(client_accuracies):
        plt.plot(rounds, acc, label=f'Client {i} Accuracy', marker='o')
    plt.xlabel('Communication Rounds')
    plt.ylabel('Accuracy (%)')
    plt.title('Client and Server Accuracies over Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # Baseline Model
#
# This is the baseline model used as a reference point for further development and evaluation.

# %%
def run_baseline_model():
    
    client_train_loaders, client_val_loaders, server_val_loader, test_loader, client_class_distributions = load_and_partition_data()
    num_clients = len(client_train_loaders)
    
    global_model = SimpleCNN().to(device)
    client_models = [copy.deepcopy(global_model).to(device) for _ in range(num_clients)]
    
    global_optimizer = optim.SGD(global_model.parameters(), lr=LEARNING_RATE)
    client_optimizers = [optim.SGD(model.parameters(), lr=LEARNING_RATE) for model in client_models]
    
    round_server_acc_list = []
    round_client_acc_list = [ [] for _ in range(num_clients) ]
    
    for br in range(COMM_ROUND):
        print("\n" + "=" * 20 + f" COMM ROUND {br + 1} " + "=" * 20)

        print("\n--- LOCAL TRAINING OF CLIENTS ---")
        for i in range(num_clients):
            print(f"\n--- Client {i} Local Training ---")
            client_local_train(client_models[i], client_train_loaders[i], client_optimizers[i], CLIENT_TEMPERATURE, epochs=NUM_EPOCHS)
            local_acc = evaluate_model(client_models[i], client_val_loaders[i])
            print(f"Client {i} Private Data Validation Accuracy: {local_acc:.2f}%")

            
        clients_logits = []
        for i in range(num_clients):
            print(f"\n--- Client {i} Generating Logits on Public Data ---")
            clients_logits.append(client_predict_logits(client_models[i], server_val_loader))

        # compute aggregated logits using client logits
        aggregated_logits = aggregate_logits(clients_logits)
        
        # server distillation update (global model update)
        print("\n--- Server KD Distillation Update ---")
        server_distillation_update(global_model, server_val_loader, aggregated_logits, global_optimizer, DISTILLATION_TEMPERATURE, epochs=SERVER_EPOCHS)
        pub_server_acc = evaluate_model(global_model, server_val_loader)
        print(f"Server Public Data Validation Accuracy: {pub_server_acc:.2f}%")
        round_server_acc_list.append(pub_server_acc)
        
        client_pub_pre_distillation = []
        for i in range(num_clients):         # evaluate & record clients' public data validation accuracy before client distillation update

            pre_acc = evaluate_model(client_models[i], server_val_loader)
            client_pub_pre_distillation.append(pre_acc)
            print(f"Client {i} Public Data Validation Accuracy before distillation: {pre_acc:.2f}%")
        
        
        client_epoch_progress_round = [] ## each client performs a distillation update with epoch-wise progress reporting
        for i in range(num_clients):
            print(f"\n--- Client {i} Distillation Update ---")
            epoch_accs = client_distillation_update(client_models[i], server_val_loader, aggregated_logits, client_optimizers[i], DISTILLATION_TEMPERATURE, epochs=DISTILLATION_CLIENT_EPOCHS)
            client_epoch_progress_round.append(epoch_accs)
            round_client_acc_list[i].append(epoch_accs[-1])
        
        # for showing client improvement (epoch-wise) for the round
        plt.figure(figsize=(8, 6))
        for i, epoch_accs in enumerate(client_epoch_progress_round):
            epochs_range = list(range(1, len(epoch_accs) + 1))
            line, = plt.plot(epochs_range, epoch_accs, marker='o', label=f'Client {i}')
            color = line.get_color()
            # mark pre-distillation accuracy at epoch 0
            plt.scatter(0, client_pub_pre_distillation[i], marker='X', s=100, color=color,
                        label=f'Client {i} Pre-Distillation' if br == 0 else "")
        plt.xlabel('Distillation Epoch')
        plt.ylabel('Accuracy (%)')
        plt.title(f'Client Improvement During Distillation (Comm Round {br + 1})')
        plt.legend()
        plt.grid(True)
        plt.show()

    
    rounds = list(range(1, COMM_ROUND + 1)) # plot overall server accuracy over rounds
    plt.figure(figsize=(8, 6))
    plt.plot(rounds, round_server_acc_list, marker='o', label='Server Accuracy')
    plt.xlabel('Comm Rounds')
    plt.ylabel('Accuracy (%)')
    plt.title('Server Accuracy over Comm Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

    # plot overall final post-round client accuracies over comm rounds
    plt.figure(figsize=(8, 6))
    for i in range(num_clients):
        plt.plot(rounds, round_client_acc_list[i], marker='o', label=f'Client {i} Accuracy')
    plt.xlabel('Comm Rounds')
    plt.ylabel('Accuracy (%)')
    plt.title('Client Final Post-Round Accuracy over Comm Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()

    print("\n--- Clients Final Evaluation on Private Data sets ---")
    for i in range(num_clients):
        print(f"\n--- Client {i} Evaluation ---")
        local_acc = evaluate_model(client_models[i], client_val_loaders[i])
        print(f"Client {i} Final Private Data Validation Accuracy: {local_acc:.2f}%")

    
    final_test_acc = evaluate_model(global_model, test_loader)
    print(f"\nFinal Server Test Accuracy (on Public test_set): {final_test_acc:.2f}%")

# %% [markdown]
# # Running the baseline.

# %%
# Hyperparameters
BATCH_SIZE = 64
LEARNING_RATE = 0.01
DISTILLATION_CLIENT_EPOCHS = 5
NUM_EPOCHS = 5
SERVER_EPOCHS = 10
ALPHA = 1  # Dirichlet distribution concentration parameter (lower = more skewed)
NUM_OF_CLIENTS = 4
CLIENT_TEMPERATURE = 1
DISTILLATION_TEMPERATURE = 3
COMM_ROUND = 10 #the communication round

run_baseline_model()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:02<00:00, 73.9MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Data partitioning complete.
# Client 0 class distribution:
#   Class 0: 0.03
#   Class 1: 0.03
#   Class 2: 0.06
#   Class 3: 0.29
#   Class 4: 0.07
#   Class 5: 0.20
#   Class 6: 0.08
#   Class 7: 0.17
#   Class 8: 0.00
#   Class 9: 0.07
# Client 1 class distribution:
#   Class 0: 0.23
#   Class 1: 0.03
#   Class 2: 0.09
#   Class 3: 0.04
#   Class 4: 0.16
#   Class 5: 0.03
#   Class 6: 0.22
#   Class 7: 0.01
#   Class 8: 0.16
#   Class 9: 0.02
# Client 2 class distribution:
#   Class 0: 0.10
#   Class 1: 0.01
#   Class 2: 0.00
#   Class 3: 0.04
#   Class 4: 0.12
#   Class 5: 0.08
#   Class 6: 0.03
#   Class 7: 0.20
#   Class 8: 0.18
#   Class 9: 0.23
# Client 3 class distribution:
#   Class 0: 0.06
#   Class 1: 0.29
#   Class 2: 0.21
#   Class 3: 0.03
#   Class 4: 0.06
#   Class 5: 0.08
#   Class 6: 0.08
#   Class 7: 0.03
#   Class 8: 0.07
#   Class 9: 0.09
#
# ==================== COMM ROUND 1 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 2.0992
# Client local training - Epoch [2/5], Loss: 1.9395
# Client local training - Epoch [3/5], Loss: 1.9110
# Client local training - Epoch [4/5], Loss: 1.8764
# Client local training - Epoch [5/5], Loss: 1.8485
# Client 0 Private Data Validation Accuracy: 29.93%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 2.1257
# Client local training - Epoch [2/5], Loss: 1.9441
# Client local training - Epoch [3/5], Loss: 1.8220
# Client local training - Epoch [4/5], Loss: 1.6677
# Client local training - Epoch [5/5], Loss: 1.6101
# Client 1 Private Data Validation Accuracy: 42.84%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 2.1084
# Client local training - Epoch [2/5], Loss: 1.8965
# Client local training - Epoch [3/5], Loss: 1.7971
# Client local training - Epoch [4/5], Loss: 1.7458
# Client local training - Epoch [5/5], Loss: 1.6873
# Client 2 Private Data Validation Accuracy: 41.52%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 2.1042
# Client local training - Epoch [2/5], Loss: 1.9806
# Client local training - Epoch [3/5], Loss: 1.9094
# Client local training - Epoch [4/5], Loss: 1.8277
# Client local training - Epoch [5/5], Loss: 1.7537
# Client 3 Private Data Validation Accuracy: 40.31%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1987
# Server KD distillation - Epoch [2/10], Loss: 0.1818
# Server KD distillation - Epoch [3/10], Loss: 0.1651
# Server KD distillation - Epoch [4/10], Loss: 0.1508
# Server KD distillation - Epoch [5/10], Loss: 0.1325
# Server KD distillation - Epoch [6/10], Loss: 0.0993
# Server KD distillation - Epoch [7/10], Loss: 0.0589
# Server KD distillation - Epoch [8/10], Loss: 0.0438
# Server KD distillation - Epoch [9/10], Loss: 0.0401
# Server KD distillation - Epoch [10/10], Loss: 0.0370
# Server Public Data Validation Accuracy: 16.92%
# Client 0 Public Data Validation Accuracy before distillation: 12.94%
# Client 1 Public Data Validation Accuracy before distillation: 22.14%
# Client 2 Public Data Validation Accuracy before distillation: 21.78%
# Client 3 Public Data Validation Accuracy before distillation: 21.44%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0776, Accuracy: 16.78%
# Client distillation update - Epoch [2/5], Loss: 0.0466, Accuracy: 17.40%
# Client distillation update - Epoch [3/5], Loss: 0.0406, Accuracy: 17.96%
# Client distillation update - Epoch [4/5], Loss: 0.0373, Accuracy: 18.22%
# Client distillation update - Epoch [5/5], Loss: 0.0339, Accuracy: 18.52%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0627, Accuracy: 23.56%
# Client distillation update - Epoch [2/5], Loss: 0.0234, Accuracy: 23.08%
# Client distillation update - Epoch [3/5], Loss: 0.0177, Accuracy: 24.00%
# Client distillation update - Epoch [4/5], Loss: 0.0158, Accuracy: 24.12%
# Client distillation update - Epoch [5/5], Loss: 0.0147, Accuracy: 24.52%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0425, Accuracy: 24.16%
# Client distillation update - Epoch [2/5], Loss: 0.0185, Accuracy: 24.68%
# Client distillation update - Epoch [3/5], Loss: 0.0160, Accuracy: 24.58%
# Client distillation update - Epoch [4/5], Loss: 0.0148, Accuracy: 25.18%
# Client distillation update - Epoch [5/5], Loss: 0.0138, Accuracy: 25.22%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0392, Accuracy: 24.36%
# Client distillation update - Epoch [2/5], Loss: 0.0235, Accuracy: 24.36%
# Client distillation update - Epoch [3/5], Loss: 0.0201, Accuracy: 24.36%
# Client distillation update - Epoch [4/5], Loss: 0.0181, Accuracy: 24.82%
# Client distillation update - Epoch [5/5], Loss: 0.0159, Accuracy: 25.00%
# ==================== COMM ROUND 2 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.8349
# Client local training - Epoch [2/5], Loss: 1.8033
# Client local training - Epoch [3/5], Loss: 1.7805
# Client local training - Epoch [4/5], Loss: 1.7528
# Client local training - Epoch [5/5], Loss: 1.7153
# Client 0 Private Data Validation Accuracy: 36.46%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.6042
# Client local training - Epoch [2/5], Loss: 1.5472
# Client local training - Epoch [3/5], Loss: 1.5220
# Client local training - Epoch [4/5], Loss: 1.4937
# Client local training - Epoch [5/5], Loss: 1.4705
# Client 1 Private Data Validation Accuracy: 42.36%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.6086
# Client local training - Epoch [2/5], Loss: 1.5239
# Client local training - Epoch [3/5], Loss: 1.4822
# Client local training - Epoch [4/5], Loss: 1.4508
# Client local training - Epoch [5/5], Loss: 1.4173
# Client 2 Private Data Validation Accuracy: 52.81%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.6783
# Client local training - Epoch [2/5], Loss: 1.5867
# Client local training - Epoch [3/5], Loss: 1.5325
# Client local training - Epoch [4/5], Loss: 1.4860
# Client local training - Epoch [5/5], Loss: 1.4465
# Client 3 Private Data Validation Accuracy: 46.99%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2686
# Server KD distillation - Epoch [2/10], Loss: 0.2443
# Server KD distillation - Epoch [3/10], Loss: 0.2196
# Server KD distillation - Epoch [4/10], Loss: 0.1818
# Server KD distillation - Epoch [5/10], Loss: 0.1331
# Server KD distillation - Epoch [6/10], Loss: 0.0955
# Server KD distillation - Epoch [7/10], Loss: 0.0802
# Server KD distillation - Epoch [8/10], Loss: 0.0742
# Server KD distillation - Epoch [9/10], Loss: 0.0685
# Server KD distillation - Epoch [10/10], Loss: 0.0639
# Server Public Data Validation Accuracy: 22.92%
# Client 0 Public Data Validation Accuracy before distillation: 19.74%
# Client 1 Public Data Validation Accuracy before distillation: 22.42%
# Client 2 Public Data Validation Accuracy before distillation: 29.10%
# Client 3 Public Data Validation Accuracy before distillation: 26.84%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1552, Accuracy: 21.88%
# Client distillation update - Epoch [2/5], Loss: 0.0902, Accuracy: 22.54%
# Client distillation update - Epoch [3/5], Loss: 0.0711, Accuracy: 19.96%
# Client distillation update - Epoch [4/5], Loss: 0.0641, Accuracy: 22.00%
# Client distillation update - Epoch [5/5], Loss: 0.0557, Accuracy: 22.24%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0769, Accuracy: 27.32%
# Client distillation update - Epoch [2/5], Loss: 0.0538, Accuracy: 27.42%
# Client distillation update - Epoch [3/5], Loss: 0.0489, Accuracy: 28.60%
# Client distillation update - Epoch [4/5], Loss: 0.0450, Accuracy: 28.08%
# Client distillation update - Epoch [5/5], Loss: 0.0437, Accuracy: 28.32%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0726, Accuracy: 30.68%
# Client distillation update - Epoch [2/5], Loss: 0.0476, Accuracy: 30.24%
# Client distillation update - Epoch [3/5], Loss: 0.0420, Accuracy: 29.68%
# Client distillation update - Epoch [4/5], Loss: 0.0404, Accuracy: 30.88%
# Client distillation update - Epoch [5/5], Loss: 0.0375, Accuracy: 30.22%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0702, Accuracy: 33.40%
# Client distillation update - Epoch [2/5], Loss: 0.0408, Accuracy: 32.46%
# Client distillation update - Epoch [3/5], Loss: 0.0368, Accuracy: 33.18%
# Client distillation update - Epoch [4/5], Loss: 0.0349, Accuracy: 32.74%
# Client distillation update - Epoch [5/5], Loss: 0.0328, Accuracy: 32.24%
# ==================== COMM ROUND 3 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.6644
# Client local training - Epoch [2/5], Loss: 1.6025
# Client local training - Epoch [3/5], Loss: 1.5665
# Client local training - Epoch [4/5], Loss: 1.5312
# Client local training - Epoch [5/5], Loss: 1.4939
# Client 0 Private Data Validation Accuracy: 41.94%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.4548
# Client local training - Epoch [2/5], Loss: 1.4148
# Client local training - Epoch [3/5], Loss: 1.3913
# Client local training - Epoch [4/5], Loss: 1.3652
# Client local training - Epoch [5/5], Loss: 1.3472
# Client 1 Private Data Validation Accuracy: 50.44%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.4040
# Client local training - Epoch [2/5], Loss: 1.3518
# Client local training - Epoch [3/5], Loss: 1.3279
# Client local training - Epoch [4/5], Loss: 1.2995
# Client local training - Epoch [5/5], Loss: 1.2786
# Client 2 Private Data Validation Accuracy: 56.19%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.4371
# Client local training - Epoch [2/5], Loss: 1.3789
# Client local training - Epoch [3/5], Loss: 1.3507
# Client local training - Epoch [4/5], Loss: 1.3177
# Client local training - Epoch [5/5], Loss: 1.2978
# Client 3 Private Data Validation Accuracy: 55.54%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2240
# Server KD distillation - Epoch [2/10], Loss: 0.2001
# Server KD distillation - Epoch [3/10], Loss: 0.1780
# Server KD distillation - Epoch [4/10], Loss: 0.1620
# Server KD distillation - Epoch [5/10], Loss: 0.1499
# Server KD distillation - Epoch [6/10], Loss: 0.1345
# Server KD distillation - Epoch [7/10], Loss: 0.1168
# Server KD distillation - Epoch [8/10], Loss: 0.1076
# Server KD distillation - Epoch [9/10], Loss: 0.1025
# Server KD distillation - Epoch [10/10], Loss: 0.0952
# Server Public Data Validation Accuracy: 29.32%
# Client 0 Public Data Validation Accuracy before distillation: 26.56%
# Client 1 Public Data Validation Accuracy before distillation: 26.26%
# Client 2 Public Data Validation Accuracy before distillation: 31.44%
# Client 3 Public Data Validation Accuracy before distillation: 37.92%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1127, Accuracy: 32.98%
# Client distillation update - Epoch [2/5], Loss: 0.0807, Accuracy: 30.72%
# Client distillation update - Epoch [3/5], Loss: 0.0753, Accuracy: 33.68%
# Client distillation update - Epoch [4/5], Loss: 0.0671, Accuracy: 34.12%
# Client distillation update - Epoch [5/5], Loss: 0.0651, Accuracy: 34.20%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0990, Accuracy: 31.98%
# Client distillation update - Epoch [2/5], Loss: 0.0809, Accuracy: 32.08%
# Client distillation update - Epoch [3/5], Loss: 0.0709, Accuracy: 33.90%
# Client distillation update - Epoch [4/5], Loss: 0.0643, Accuracy: 32.50%
# Client distillation update - Epoch [5/5], Loss: 0.0638, Accuracy: 33.14%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0979, Accuracy: 35.76%
# Client distillation update - Epoch [2/5], Loss: 0.0702, Accuracy: 33.68%
# Client distillation update - Epoch [3/5], Loss: 0.0656, Accuracy: 35.22%
# Client distillation update - Epoch [4/5], Loss: 0.0588, Accuracy: 33.90%
# Client distillation update - Epoch [5/5], Loss: 0.0571, Accuracy: 36.16%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0836, Accuracy: 36.20%
# Client distillation update - Epoch [2/5], Loss: 0.0639, Accuracy: 37.26%
# Client distillation update - Epoch [3/5], Loss: 0.0592, Accuracy: 36.50%
# Client distillation update - Epoch [4/5], Loss: 0.0549, Accuracy: 35.92%
# Client distillation update - Epoch [5/5], Loss: 0.0539, Accuracy: 35.98%
# ==================== COMM ROUND 4 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.4753
# Client local training - Epoch [2/5], Loss: 1.4354
# Client local training - Epoch [3/5], Loss: 1.4116
# Client local training - Epoch [4/5], Loss: 1.3915
# Client local training - Epoch [5/5], Loss: 1.3696
# Client 0 Private Data Validation Accuracy: 41.59%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.3358
# Client local training - Epoch [2/5], Loss: 1.3064
# Client local training - Epoch [3/5], Loss: 1.2789
# Client local training - Epoch [4/5], Loss: 1.2663
# Client local training - Epoch [5/5], Loss: 1.2449
# Client 1 Private Data Validation Accuracy: 50.44%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.2678
# Client local training - Epoch [2/5], Loss: 1.2307
# Client local training - Epoch [3/5], Loss: 1.2081
# Client local training - Epoch [4/5], Loss: 1.1897
# Client local training - Epoch [5/5], Loss: 1.1676
# Client 2 Private Data Validation Accuracy: 59.51%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.2915
# Client local training - Epoch [2/5], Loss: 1.2549
# Client local training - Epoch [3/5], Loss: 1.2320
# Client local training - Epoch [4/5], Loss: 1.2134
# Client local training - Epoch [5/5], Loss: 1.1959
# Client 3 Private Data Validation Accuracy: 57.08%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2655
# Server KD distillation - Epoch [2/10], Loss: 0.2257
# Server KD distillation - Epoch [3/10], Loss: 0.1968
# Server KD distillation - Epoch [4/10], Loss: 0.1707
# Server KD distillation - Epoch [5/10], Loss: 0.1542
# Server KD distillation - Epoch [6/10], Loss: 0.1471
# Server KD distillation - Epoch [7/10], Loss: 0.1317
# Server KD distillation - Epoch [8/10], Loss: 0.1279
# Server KD distillation - Epoch [9/10], Loss: 0.1173
# Server KD distillation - Epoch [10/10], Loss: 0.1118
# Server Public Data Validation Accuracy: 31.08%
# Client 0 Public Data Validation Accuracy before distillation: 36.38%
# Client 1 Public Data Validation Accuracy before distillation: 28.10%
# Client 2 Public Data Validation Accuracy before distillation: 36.50%
# Client 3 Public Data Validation Accuracy before distillation: 42.36%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1418, Accuracy: 40.00%
# Client distillation update - Epoch [2/5], Loss: 0.1030, Accuracy: 40.58%
# Client distillation update - Epoch [3/5], Loss: 0.0901, Accuracy: 37.72%
# Client distillation update - Epoch [4/5], Loss: 0.0884, Accuracy: 39.96%
# Client distillation update - Epoch [5/5], Loss: 0.0816, Accuracy: 39.30%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1234, Accuracy: 41.00%
# Client distillation update - Epoch [2/5], Loss: 0.0901, Accuracy: 37.14%
# Client distillation update - Epoch [3/5], Loss: 0.0894, Accuracy: 38.66%
# Client distillation update - Epoch [4/5], Loss: 0.0788, Accuracy: 38.80%
# Client distillation update - Epoch [5/5], Loss: 0.0790, Accuracy: 37.22%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1092, Accuracy: 39.60%
# Client distillation update - Epoch [2/5], Loss: 0.0891, Accuracy: 41.16%
# Client distillation update - Epoch [3/5], Loss: 0.0786, Accuracy: 39.28%
# Client distillation update - Epoch [4/5], Loss: 0.0761, Accuracy: 41.04%
# Client distillation update - Epoch [5/5], Loss: 0.0686, Accuracy: 38.98%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0981, Accuracy: 37.44%
# Client distillation update - Epoch [2/5], Loss: 0.0852, Accuracy: 37.90%
# Client distillation update - Epoch [3/5], Loss: 0.0775, Accuracy: 40.32%
# Client distillation update - Epoch [4/5], Loss: 0.0694, Accuracy: 40.72%
# Client distillation update - Epoch [5/5], Loss: 0.0672, Accuracy: 40.68%
# ==================== COMM ROUND 5 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.3586
# Client local training - Epoch [2/5], Loss: 1.3331
# Client local training - Epoch [3/5], Loss: 1.3100
# Client local training - Epoch [4/5], Loss: 1.3047
# Client local training - Epoch [5/5], Loss: 1.2813
# Client 0 Private Data Validation Accuracy: 48.16%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.2462
# Client local training - Epoch [2/5], Loss: 1.2121
# Client local training - Epoch [3/5], Loss: 1.1915
# Client local training - Epoch [4/5], Loss: 1.1833
# Client local training - Epoch [5/5], Loss: 1.1745
# Client 1 Private Data Validation Accuracy: 56.82%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1657
# Client local training - Epoch [2/5], Loss: 1.1300
# Client local training - Epoch [3/5], Loss: 1.1197
# Client local training - Epoch [4/5], Loss: 1.0946
# Client local training - Epoch [5/5], Loss: 1.0857
# Client 2 Private Data Validation Accuracy: 59.61%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1982
# Client local training - Epoch [2/5], Loss: 1.1622
# Client local training - Epoch [3/5], Loss: 1.1463
# Client local training - Epoch [4/5], Loss: 1.1296
# Client local training - Epoch [5/5], Loss: 1.1065
# Client 3 Private Data Validation Accuracy: 59.19%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2158
# Server KD distillation - Epoch [2/10], Loss: 0.1968
# Server KD distillation - Epoch [3/10], Loss: 0.1722
# Server KD distillation - Epoch [4/10], Loss: 0.1614
# Server KD distillation - Epoch [5/10], Loss: 0.1505
# Server KD distillation - Epoch [6/10], Loss: 0.1373
# Server KD distillation - Epoch [7/10], Loss: 0.1268
# Server KD distillation - Epoch [8/10], Loss: 0.1219
# Server KD distillation - Epoch [9/10], Loss: 0.1185
# Server KD distillation - Epoch [10/10], Loss: 0.1106
# Server Public Data Validation Accuracy: 36.04%
# Client 0 Public Data Validation Accuracy before distillation: 36.30%
# Client 1 Public Data Validation Accuracy before distillation: 36.24%
# Client 2 Public Data Validation Accuracy before distillation: 35.28%
# Client 3 Public Data Validation Accuracy before distillation: 43.04%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1569, Accuracy: 41.64%
# Client distillation update - Epoch [2/5], Loss: 0.1069, Accuracy: 40.04%
# Client distillation update - Epoch [3/5], Loss: 0.0952, Accuracy: 39.98%
# Client distillation update - Epoch [4/5], Loss: 0.0954, Accuracy: 38.84%
# Client distillation update - Epoch [5/5], Loss: 0.0864, Accuracy: 40.32%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1393, Accuracy: 38.80%
# Client distillation update - Epoch [2/5], Loss: 0.1156, Accuracy: 38.80%
# Client distillation update - Epoch [3/5], Loss: 0.0956, Accuracy: 38.80%
# Client distillation update - Epoch [4/5], Loss: 0.0882, Accuracy: 40.42%
# Client distillation update - Epoch [5/5], Loss: 0.0796, Accuracy: 40.38%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1184, Accuracy: 40.70%
# Client distillation update - Epoch [2/5], Loss: 0.0922, Accuracy: 40.14%
# Client distillation update - Epoch [3/5], Loss: 0.0932, Accuracy: 40.54%
# Client distillation update - Epoch [4/5], Loss: 0.0799, Accuracy: 40.04%
# Client distillation update - Epoch [5/5], Loss: 0.0771, Accuracy: 41.52%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1084, Accuracy: 39.90%
# Client distillation update - Epoch [2/5], Loss: 0.0834, Accuracy: 40.42%
# Client distillation update - Epoch [3/5], Loss: 0.0789, Accuracy: 42.30%
# Client distillation update - Epoch [4/5], Loss: 0.0752, Accuracy: 40.66%
# Client distillation update - Epoch [5/5], Loss: 0.0733, Accuracy: 42.14%
# ==================== COMM ROUND 6 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.2778
# Client local training - Epoch [2/5], Loss: 1.2520
# Client local training - Epoch [3/5], Loss: 1.2331
# Client local training - Epoch [4/5], Loss: 1.2226
# Client local training - Epoch [5/5], Loss: 1.2058
# Client 0 Private Data Validation Accuracy: 50.96%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1646
# Client local training - Epoch [2/5], Loss: 1.1361
# Client local training - Epoch [3/5], Loss: 1.1334
# Client local training - Epoch [4/5], Loss: 1.1076
# Client local training - Epoch [5/5], Loss: 1.0930
# Client 1 Private Data Validation Accuracy: 58.66%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0770
# Client local training - Epoch [2/5], Loss: 1.0517
# Client local training - Epoch [3/5], Loss: 1.0391
# Client local training - Epoch [4/5], Loss: 1.0308
# Client local training - Epoch [5/5], Loss: 1.0114
# Client 2 Private Data Validation Accuracy: 61.61%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1181
# Client local training - Epoch [2/5], Loss: 1.0823
# Client local training - Epoch [3/5], Loss: 1.0713
# Client local training - Epoch [4/5], Loss: 1.0510
# Client local training - Epoch [5/5], Loss: 1.0371
# Client 3 Private Data Validation Accuracy: 60.87%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2190
# Server KD distillation - Epoch [2/10], Loss: 0.1902
# Server KD distillation - Epoch [3/10], Loss: 0.1726
# Server KD distillation - Epoch [4/10], Loss: 0.1664
# Server KD distillation - Epoch [5/10], Loss: 0.1487
# Server KD distillation - Epoch [6/10], Loss: 0.1466
# Server KD distillation - Epoch [7/10], Loss: 0.1369
# Server KD distillation - Epoch [8/10], Loss: 0.1288
# Server KD distillation - Epoch [9/10], Loss: 0.1258
# Server KD distillation - Epoch [10/10], Loss: 0.1108
# Server Public Data Validation Accuracy: 38.00%
# Client 0 Public Data Validation Accuracy before distillation: 40.72%
# Client 1 Public Data Validation Accuracy before distillation: 36.48%
# Client 2 Public Data Validation Accuracy before distillation: 39.20%
# Client 3 Public Data Validation Accuracy before distillation: 43.52%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1693, Accuracy: 44.70%
# Client distillation update - Epoch [2/5], Loss: 0.1182, Accuracy: 42.06%
# Client distillation update - Epoch [3/5], Loss: 0.1185, Accuracy: 43.06%
# Client distillation update - Epoch [4/5], Loss: 0.1055, Accuracy: 43.10%
# Client distillation update - Epoch [5/5], Loss: 0.1058, Accuracy: 44.48%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1753, Accuracy: 42.14%
# Client distillation update - Epoch [2/5], Loss: 0.1272, Accuracy: 43.04%
# Client distillation update - Epoch [3/5], Loss: 0.1212, Accuracy: 43.18%
# Client distillation update - Epoch [4/5], Loss: 0.1009, Accuracy: 43.12%
# Client distillation update - Epoch [5/5], Loss: 0.1015, Accuracy: 45.24%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1409, Accuracy: 43.60%
# Client distillation update - Epoch [2/5], Loss: 0.1088, Accuracy: 42.64%
# Client distillation update - Epoch [3/5], Loss: 0.1048, Accuracy: 43.88%
# Client distillation update - Epoch [4/5], Loss: 0.0918, Accuracy: 43.62%
# Client distillation update - Epoch [5/5], Loss: 0.0945, Accuracy: 44.04%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1238, Accuracy: 42.62%
# Client distillation update - Epoch [2/5], Loss: 0.1033, Accuracy: 43.98%
# Client distillation update - Epoch [3/5], Loss: 0.0970, Accuracy: 45.88%
# Client distillation update - Epoch [4/5], Loss: 0.0915, Accuracy: 44.70%
# Client distillation update - Epoch [5/5], Loss: 0.0864, Accuracy: 45.36%
# ==================== COMM ROUND 7 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.2085
# Client local training - Epoch [2/5], Loss: 1.1783
# Client local training - Epoch [3/5], Loss: 1.1639
# Client local training - Epoch [4/5], Loss: 1.1486
# Client local training - Epoch [5/5], Loss: 1.1335
# Client 0 Private Data Validation Accuracy: 51.05%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1002
# Client local training - Epoch [2/5], Loss: 1.0642
# Client local training - Epoch [3/5], Loss: 1.0569
# Client local training - Epoch [4/5], Loss: 1.0426
# Client local training - Epoch [5/5], Loss: 1.0299
# Client 1 Private Data Validation Accuracy: 59.67%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0100
# Client local training - Epoch [2/5], Loss: 0.9835
# Client local training - Epoch [3/5], Loss: 0.9704
# Client local training - Epoch [4/5], Loss: 0.9481
# Client local training - Epoch [5/5], Loss: 0.9402
# Client 2 Private Data Validation Accuracy: 62.74%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0449
# Client local training - Epoch [2/5], Loss: 1.0183
# Client local training - Epoch [3/5], Loss: 1.0007
# Client local training - Epoch [4/5], Loss: 0.9882
# Client local training - Epoch [5/5], Loss: 0.9720
# Client 3 Private Data Validation Accuracy: 64.14%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2023
# Server KD distillation - Epoch [2/10], Loss: 0.1787
# Server KD distillation - Epoch [3/10], Loss: 0.1691
# Server KD distillation - Epoch [4/10], Loss: 0.1577
# Server KD distillation - Epoch [5/10], Loss: 0.1437
# Server KD distillation - Epoch [6/10], Loss: 0.1391
# Server KD distillation - Epoch [7/10], Loss: 0.1333
# Server KD distillation - Epoch [8/10], Loss: 0.1256
# Server KD distillation - Epoch [9/10], Loss: 0.1203
# Server KD distillation - Epoch [10/10], Loss: 0.1122
# Server Public Data Validation Accuracy: 38.72%
# Client 0 Public Data Validation Accuracy before distillation: 40.72%
# Client 1 Public Data Validation Accuracy before distillation: 42.82%
# Client 2 Public Data Validation Accuracy before distillation: 42.22%
# Client 3 Public Data Validation Accuracy before distillation: 48.52%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1923, Accuracy: 44.56%
# Client distillation update - Epoch [2/5], Loss: 0.1317, Accuracy: 44.88%
# Client distillation update - Epoch [3/5], Loss: 0.1196, Accuracy: 45.72%
# Client distillation update - Epoch [4/5], Loss: 0.1068, Accuracy: 44.16%
# Client distillation update - Epoch [5/5], Loss: 0.1029, Accuracy: 45.36%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2084, Accuracy: 41.32%
# Client distillation update - Epoch [2/5], Loss: 0.1395, Accuracy: 44.66%
# Client distillation update - Epoch [3/5], Loss: 0.1184, Accuracy: 41.86%
# Client distillation update - Epoch [4/5], Loss: 0.1129, Accuracy: 45.08%
# Client distillation update - Epoch [5/5], Loss: 0.1085, Accuracy: 45.38%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1683, Accuracy: 40.58%
# Client distillation update - Epoch [2/5], Loss: 0.1171, Accuracy: 43.04%
# Client distillation update - Epoch [3/5], Loss: 0.1129, Accuracy: 42.88%
# Client distillation update - Epoch [4/5], Loss: 0.1058, Accuracy: 44.90%
# Client distillation update - Epoch [5/5], Loss: 0.0941, Accuracy: 45.30%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1367, Accuracy: 43.30%
# Client distillation update - Epoch [2/5], Loss: 0.1108, Accuracy: 47.18%
# Client distillation update - Epoch [3/5], Loss: 0.0997, Accuracy: 46.40%
# Client distillation update - Epoch [4/5], Loss: 0.0984, Accuracy: 46.50%
# Client distillation update - Epoch [5/5], Loss: 0.0926, Accuracy: 47.30%
# ==================== COMM ROUND 8 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1427
# Client local training - Epoch [2/5], Loss: 1.1142
# Client local training - Epoch [3/5], Loss: 1.0924
# Client local training - Epoch [4/5], Loss: 1.0748
# Client local training - Epoch [5/5], Loss: 1.0663
# Client 0 Private Data Validation Accuracy: 53.99%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0304
# Client local training - Epoch [2/5], Loss: 1.0045
# Client local training - Epoch [3/5], Loss: 0.9910
# Client local training - Epoch [4/5], Loss: 0.9759
# Client local training - Epoch [5/5], Loss: 0.9584
# Client 1 Private Data Validation Accuracy: 60.20%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9433
# Client local training - Epoch [2/5], Loss: 0.9098
# Client local training - Epoch [3/5], Loss: 0.9039
# Client local training - Epoch [4/5], Loss: 0.8819
# Client local training - Epoch [5/5], Loss: 0.8637
# Client 2 Private Data Validation Accuracy: 65.67%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9793
# Client local training - Epoch [2/5], Loss: 0.9523
# Client local training - Epoch [3/5], Loss: 0.9362
# Client local training - Epoch [4/5], Loss: 0.9213
# Client local training - Epoch [5/5], Loss: 0.9046
# Client 3 Private Data Validation Accuracy: 63.37%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1968
# Server KD distillation - Epoch [2/10], Loss: 0.1751
# Server KD distillation - Epoch [3/10], Loss: 0.1704
# Server KD distillation - Epoch [4/10], Loss: 0.1479
# Server KD distillation - Epoch [5/10], Loss: 0.1463
# Server KD distillation - Epoch [6/10], Loss: 0.1381
# Server KD distillation - Epoch [7/10], Loss: 0.1332
# Server KD distillation - Epoch [8/10], Loss: 0.1263
# Server KD distillation - Epoch [9/10], Loss: 0.1287
# Server KD distillation - Epoch [10/10], Loss: 0.1163
# Server Public Data Validation Accuracy: 42.38%
# Client 0 Public Data Validation Accuracy before distillation: 44.76%
# Client 1 Public Data Validation Accuracy before distillation: 41.36%
# Client 2 Public Data Validation Accuracy before distillation: 43.22%
# Client 3 Public Data Validation Accuracy before distillation: 50.02%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1985, Accuracy: 47.86%
# Client distillation update - Epoch [2/5], Loss: 0.1307, Accuracy: 44.26%
# Client distillation update - Epoch [3/5], Loss: 0.1293, Accuracy: 45.56%
# Client distillation update - Epoch [4/5], Loss: 0.1164, Accuracy: 48.30%
# Client distillation update - Epoch [5/5], Loss: 0.1118, Accuracy: 47.70%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2145, Accuracy: 41.04%
# Client distillation update - Epoch [2/5], Loss: 0.1401, Accuracy: 47.26%
# Client distillation update - Epoch [3/5], Loss: 0.1227, Accuracy: 47.18%
# Client distillation update - Epoch [4/5], Loss: 0.1220, Accuracy: 47.30%
# Client distillation update - Epoch [5/5], Loss: 0.1129, Accuracy: 48.10%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1702, Accuracy: 42.26%
# Client distillation update - Epoch [2/5], Loss: 0.1408, Accuracy: 46.14%
# Client distillation update - Epoch [3/5], Loss: 0.1155, Accuracy: 47.64%
# Client distillation update - Epoch [4/5], Loss: 0.1126, Accuracy: 47.86%
# Client distillation update - Epoch [5/5], Loss: 0.0991, Accuracy: 46.00%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1546, Accuracy: 47.82%
# Client distillation update - Epoch [2/5], Loss: 0.1195, Accuracy: 49.82%
# Client distillation update - Epoch [3/5], Loss: 0.1102, Accuracy: 48.90%
# Client distillation update - Epoch [4/5], Loss: 0.1061, Accuracy: 49.60%
# Client distillation update - Epoch [5/5], Loss: 0.0972, Accuracy: 49.44%
# ==================== COMM ROUND 9 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0694
# Client local training - Epoch [2/5], Loss: 1.0428
# Client local training - Epoch [3/5], Loss: 1.0294
# Client local training - Epoch [4/5], Loss: 1.0106
# Client local training - Epoch [5/5], Loss: 0.9985
# Client 0 Private Data Validation Accuracy: 55.70%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9637
# Client local training - Epoch [2/5], Loss: 0.9411
# Client local training - Epoch [3/5], Loss: 0.9218
# Client local training - Epoch [4/5], Loss: 0.9172
# Client local training - Epoch [5/5], Loss: 0.8977
# Client 1 Private Data Validation Accuracy: 64.02%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8763
# Client local training - Epoch [2/5], Loss: 0.8452
# Client local training - Epoch [3/5], Loss: 0.8331
# Client local training - Epoch [4/5], Loss: 0.8152
# Client local training - Epoch [5/5], Loss: 0.7991
# Client 2 Private Data Validation Accuracy: 68.17%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9117
# Client local training - Epoch [2/5], Loss: 0.8825
# Client local training - Epoch [3/5], Loss: 0.8669
# Client local training - Epoch [4/5], Loss: 0.8499
# Client local training - Epoch [5/5], Loss: 0.8373
# Client 3 Private Data Validation Accuracy: 67.17%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2054
# Server KD distillation - Epoch [2/10], Loss: 0.1729
# Server KD distillation - Epoch [3/10], Loss: 0.1767
# Server KD distillation - Epoch [4/10], Loss: 0.1634
# Server KD distillation - Epoch [5/10], Loss: 0.1610
# Server KD distillation - Epoch [6/10], Loss: 0.1561
# Server KD distillation - Epoch [7/10], Loss: 0.1463
# Server KD distillation - Epoch [8/10], Loss: 0.1350
# Server KD distillation - Epoch [9/10], Loss: 0.1302
# Server KD distillation - Epoch [10/10], Loss: 0.1217
# Server Public Data Validation Accuracy: 44.90%
# Client 0 Public Data Validation Accuracy before distillation: 47.46%
# Client 1 Public Data Validation Accuracy before distillation: 45.62%
# Client 2 Public Data Validation Accuracy before distillation: 45.28%
# Client 3 Public Data Validation Accuracy before distillation: 53.36%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2078, Accuracy: 49.34%
# Client distillation update - Epoch [2/5], Loss: 0.1577, Accuracy: 47.84%
# Client distillation update - Epoch [3/5], Loss: 0.1402, Accuracy: 46.22%
# Client distillation update - Epoch [4/5], Loss: 0.1317, Accuracy: 51.06%
# Client distillation update - Epoch [5/5], Loss: 0.1177, Accuracy: 48.56%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2085, Accuracy: 44.68%
# Client distillation update - Epoch [2/5], Loss: 0.1555, Accuracy: 48.96%
# Client distillation update - Epoch [3/5], Loss: 0.1419, Accuracy: 48.28%
# Client distillation update - Epoch [4/5], Loss: 0.1324, Accuracy: 48.72%
# Client distillation update - Epoch [5/5], Loss: 0.1253, Accuracy: 51.44%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2040, Accuracy: 47.64%
# Client distillation update - Epoch [2/5], Loss: 0.1410, Accuracy: 47.88%
# Client distillation update - Epoch [3/5], Loss: 0.1227, Accuracy: 46.56%
# Client distillation update - Epoch [4/5], Loss: 0.1242, Accuracy: 49.40%
# Client distillation update - Epoch [5/5], Loss: 0.1107, Accuracy: 50.40%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1631, Accuracy: 50.68%
# Client distillation update - Epoch [2/5], Loss: 0.1299, Accuracy: 51.16%
# Client distillation update - Epoch [3/5], Loss: 0.1212, Accuracy: 52.10%
# Client distillation update - Epoch [4/5], Loss: 0.1116, Accuracy: 51.66%
# Client distillation update - Epoch [5/5], Loss: 0.1051, Accuracy: 52.42%
# ==================== COMM ROUND 10 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0034
# Client local training - Epoch [2/5], Loss: 0.9767
# Client local training - Epoch [3/5], Loss: 0.9584
# Client local training - Epoch [4/5], Loss: 0.9454
# Client local training - Epoch [5/5], Loss: 0.9268
# Client 0 Private Data Validation Accuracy: 53.86%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8943
# Client local training - Epoch [2/5], Loss: 0.8668
# Client local training - Epoch [3/5], Loss: 0.8531
# Client local training - Epoch [4/5], Loss: 0.8398
# Client local training - Epoch [5/5], Loss: 0.8195
# Client 1 Private Data Validation Accuracy: 62.86%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8082
# Client local training - Epoch [2/5], Loss: 0.7806
# Client local training - Epoch [3/5], Loss: 0.7631
# Client local training - Epoch [4/5], Loss: 0.7427
# Client local training - Epoch [5/5], Loss: 0.7359
# Client 2 Private Data Validation Accuracy: 68.41%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8430
# Client local training - Epoch [2/5], Loss: 0.8231
# Client local training - Epoch [3/5], Loss: 0.7944
# Client local training - Epoch [4/5], Loss: 0.7867
# Client local training - Epoch [5/5], Loss: 0.7659
# Client 3 Private Data Validation Accuracy: 67.59%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.2138
# Server KD distillation - Epoch [2/10], Loss: 0.1883
# Server KD distillation - Epoch [3/10], Loss: 0.1875
# Server KD distillation - Epoch [4/10], Loss: 0.1742
# Server KD distillation - Epoch [5/10], Loss: 0.1600
# Server KD distillation - Epoch [6/10], Loss: 0.1589
# Server KD distillation - Epoch [7/10], Loss: 0.1559
# Server KD distillation - Epoch [8/10], Loss: 0.1504
# Server KD distillation - Epoch [9/10], Loss: 0.1427
# Server KD distillation - Epoch [10/10], Loss: 0.1356
# Server Public Data Validation Accuracy: 45.94%
# Client 0 Public Data Validation Accuracy before distillation: 44.54%
# Client 1 Public Data Validation Accuracy before distillation: 44.52%
# Client 2 Public Data Validation Accuracy before distillation: 45.98%
# Client 3 Public Data Validation Accuracy before distillation: 53.24%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2324, Accuracy: 50.14%
# Client distillation update - Epoch [2/5], Loss: 0.1497, Accuracy: 50.40%
# Client distillation update - Epoch [3/5], Loss: 0.1404, Accuracy: 51.36%
# Client distillation update - Epoch [4/5], Loss: 0.1418, Accuracy: 52.36%
# Client distillation update - Epoch [5/5], Loss: 0.1234, Accuracy: 52.58%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.2274, Accuracy: 49.16%
# Client distillation update - Epoch [2/5], Loss: 0.1614, Accuracy: 49.78%
# Client distillation update - Epoch [3/5], Loss: 0.1441, Accuracy: 52.22%
# Client distillation update - Epoch [4/5], Loss: 0.1334, Accuracy: 51.60%
# Client distillation update - Epoch [5/5], Loss: 0.1261, Accuracy: 51.46%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1965, Accuracy: 47.38%
# Client distillation update - Epoch [2/5], Loss: 0.1521, Accuracy: 51.16%
# Client distillation update - Epoch [3/5], Loss: 0.1428, Accuracy: 48.42%
# Client distillation update - Epoch [4/5], Loss: 0.1299, Accuracy: 49.50%
# Client distillation update - Epoch [5/5], Loss: 0.1289, Accuracy: 50.74%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1856, Accuracy: 50.06%
# Client distillation update - Epoch [2/5], Loss: 0.1463, Accuracy: 51.28%
# Client distillation update - Epoch [3/5], Loss: 0.1271, Accuracy: 54.22%
# Client distillation update - Epoch [4/5], Loss: 0.1183, Accuracy: 53.16%
# Client distillation update - Epoch [5/5], Loss: 0.1133, Accuracy: 52.64%
# --- Clients Final Evaluation on Private Data sets ---
#
# --- Client 0 Evaluation ---
# Client 0 Final Private Data Validation Accuracy: 51.71%
#
# --- Client 1 Evaluation ---
# Client 1 Final Private Data Validation Accuracy: 51.69%
#
# --- Client 2 Evaluation ---
# Client 2 Final Private Data Validation Accuracy: 60.29%
#
# --- Client 3 Evaluation ---
# Client 3 Final Private Data Validation Accuracy: 52.63%
#
# Final Server Test Accuracy (on Public test_set): 46.75%

# %% [markdown]
# # Model Improvement 1

# %%
def run_model_improvement_1():
    
    client_train_loaders, client_val_loaders, server_val_loader, test_loader, client_class_distributions = load_and_partition_data()
    num_clients = len(client_train_loaders)
    
    # compute global class distribution from client distributions
    global_distribution = calculate_global_distribution(client_class_distributions)
    
    # calculate a personalized temperature for each client based on data heterogeneity scores.
    client_temperatures = []
    for i, distribution in enumerate(client_class_distributions):
        temp = calculate_client_temperature(distribution, global_distribution)
        client_temperatures.append(temp)
        print(f"Client {i} personalized training temperature: {temp:.4f}")
    
    global_model = SimpleCNN().to(device)
    client_models = [copy.deepcopy(global_model).to(device) for _ in range(num_clients)]
    
    global_optimizer = optim.SGD(global_model.parameters(), lr=LEARNING_RATE)
    client_optimizers = [optim.SGD(model.parameters(), lr=LEARNING_RATE) for model in client_models]
    
    round_server_acc_list = []
    round_client_acc_list = [ [] for _ in range(num_clients) ]
    
    for br in range(COMM_ROUND):
        print("\n" + "=" * 20 + f" COMM ROUND {br + 1} " + "=" * 20)
    
        print("\n--- LOCAL TRAINING OF CLIENTS ---")
        for i in range(num_clients):
            print(f"\n--- Client {i} Local Training ---")
            # use the client-specific temperature calculated earlier
            client_local_train(client_models[i], client_train_loaders[i], client_optimizers[i], client_temperatures[i], epochs=NUM_EPOCHS)
            local_acc = evaluate_model(client_models[i], client_val_loaders[i])
            print(f"Client {i} Private Data Validation Accuracy: {local_acc:.2f}%")
     
        
        clients_logits = []
        for i in range(num_clients):
            print(f"\n--- Client {i} Generating Logits on Public Data ---")# logits are collected from each client
            clients_logits.append(client_predict_logits(client_models[i], server_val_loader))
    
        
        aggregated_logits = aggregate_logits(clients_logits)# compute aggregated logits using client logits
    
        
        print("\n--- Server KD Distillation Update ---") 
        # server distillation update (global model update)
        server_distillation_update(global_model, server_val_loader, aggregated_logits, global_optimizer, DISTILLATION_TEMPERATURE, epochs=SERVER_EPOCHS)
        pub_server_acc = evaluate_model(global_model, server_val_loader)
        print(f"Server Public Data Validation Accuracy: {pub_server_acc:.2f}%")
        round_server_acc_list.append(pub_server_acc)
    
        
        client_pub_pre_distillation = [] # evaluate & record clients' public data validation accuracy before client distillation update
        for i in range(num_clients):
            pre_acc = evaluate_model(client_models[i], server_val_loader)
            client_pub_pre_distillation.append(pre_acc)
            print(f"Client {i} Public Data Validation Accuracy before distillation: {pre_acc:.2f}%")
    
        
        client_epoch_progress_round = [] # each client performs a distillation update with epoch-wise progress reporting
        for i in range(num_clients):
            print(f"\n--- Client {i} Distillation Update ---")
            epoch_accs = client_distillation_update(client_models[i], server_val_loader, aggregated_logits, client_optimizers[i], DISTILLATION_TEMPERATURE, epochs=DISTILLATION_CLIENT_EPOCHS)
            client_epoch_progress_round.append(epoch_accs)
            round_client_acc_list[i].append(epoch_accs[-1])
    
        # plot client improvement (epoch-wise) for the round
        plt.figure(figsize=(8, 6))
        for i, epoch_accs in enumerate(client_epoch_progress_round):
            epochs_range = list(range(1, len(epoch_accs) + 1))
            line, = plt.plot(epochs_range, epoch_accs, marker='o', label=f'Client {i}')
            color = line.get_color()
            # mark the pre-distillation accuracy at epoch 0
            plt.scatter(0, client_pub_pre_distillation[i], marker='X', s=100, color=color,
                        label=f'Client {i} Pre-Distillation' if br == 0 else "")
        plt.xlabel('Distillation Epoch')
        plt.ylabel('Accuracy (%)')
        plt.title(f'Client Improvement During Distillation (Comm Round {br + 1})')
        plt.legend()
        plt.grid(True)
        plt.show()
    
    # plot overall server accuracy over rounds
    rounds = list(range(1, COMM_ROUND + 1))
    plt.figure(figsize=(8, 6))
    plt.plot(rounds, round_server_acc_list, marker='o', label='Server Accuracy')
    plt.xlabel('Comm Rounds')
    plt.ylabel('Accuracy (%)')
    plt.title('Server Accuracy over Comm Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    # plot overall final post-round client accuracies over big rounds
    plt.figure(figsize=(8, 6))
    for i in range(num_clients):
        plt.plot(rounds, round_client_acc_list[i], marker='o', label=f'Client {i} Accuracy')
    plt.xlabel('Comm Rounds')
    plt.ylabel('Accuracy (%)')
    plt.title('Client Final Post-Round Accuracy over Comm Rounds')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    print("\n--- Clients Final Evaluation on Private Data sets ---")
    for i in range(num_clients):
        print(f"\n--- Client {i} Evaluation ---")
        local_acc = evaluate_model(client_models[i], client_val_loaders[i])
        print(f"Client {i} Final Private Data Validation Accuracy: {local_acc:.2f}%")
    
    # final testing on external test set
    final_test_acc = evaluate_model(global_model, test_loader)
    print(f"\nFinal Server Test Accuracy (on Public test_set): {final_test_acc:.2f}%")

# %% [markdown]
# # Running Model Improvement 1

# %%
# Hyperparameters
BATCH_SIZE = 64
LEARNING_RATE = 0.01
DISTILLATION_CLIENT_EPOCHS = 5
NUM_EPOCHS = 5
SERVER_EPOCHS = 10
ALPHA = 1  # Dirichlet distribution concentration parameter (lower = more skewed)
NUM_OF_CLIENTS = 4
DISTILLATION_TEMPERATURE = 3
COMM_ROUND = 10 #the communication round

run_model_improvement_1()
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Data partitioning complete.
# Client 0 class distribution:
#   Class 0: 0.03
#   Class 1: 0.03
#   Class 2: 0.06
#   Class 3: 0.29
#   Class 4: 0.07
#   Class 5: 0.20
#   Class 6: 0.08
#   Class 7: 0.17
#   Class 8: 0.00
#   Class 9: 0.07
# Client 1 class distribution:
#   Class 0: 0.23
#   Class 1: 0.03
#   Class 2: 0.09
#   Class 3: 0.04
#   Class 4: 0.16
#   Class 5: 0.03
#   Class 6: 0.22
#   Class 7: 0.01
#   Class 8: 0.16
#   Class 9: 0.02
# Client 2 class distribution:
#   Class 0: 0.10
#   Class 1: 0.01
#   Class 2: 0.00
#   Class 3: 0.04
#   Class 4: 0.12
#   Class 5: 0.08
#   Class 6: 0.03
#   Class 7: 0.20
#   Class 8: 0.18
#   Class 9: 0.23
# Client 3 class distribution:
#   Class 0: 0.06
#   Class 1: 0.29
#   Class 2: 0.21
#   Class 3: 0.03
#   Class 4: 0.06
#   Class 5: 0.08
#   Class 6: 0.08
#   Class 7: 0.03
#   Class 8: 0.07
#   Class 9: 0.09
# Client 0 personalized training temperature: 0.2892
# Client 1 personalized training temperature: 0.3038
# Client 2 personalized training temperature: 0.3477
# Client 3 personalized training temperature: 0.3424
#
# ==================== COMM ROUND 1 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.9653
# Client local training - Epoch [2/5], Loss: 1.8589
# Client local training - Epoch [3/5], Loss: 1.7866
# Client local training - Epoch [4/5], Loss: 1.7033
# Client local training - Epoch [5/5], Loss: 1.6102
# Client 0 Private Data Validation Accuracy: 41.15%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.9251
# Client local training - Epoch [2/5], Loss: 1.6426
# Client local training - Epoch [3/5], Loss: 1.5624
# Client local training - Epoch [4/5], Loss: 1.4993
# Client local training - Epoch [5/5], Loss: 1.4508
# Client 1 Private Data Validation Accuracy: 46.23%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.9390
# Client local training - Epoch [2/5], Loss: 1.7128
# Client local training - Epoch [3/5], Loss: 1.5570
# Client local training - Epoch [4/5], Loss: 1.4683
# Client local training - Epoch [5/5], Loss: 1.4043
# Client 2 Private Data Validation Accuracy: 50.76%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.9969
# Client local training - Epoch [2/5], Loss: 1.8032
# Client local training - Epoch [3/5], Loss: 1.6409
# Client local training - Epoch [4/5], Loss: 1.5244
# Client local training - Epoch [5/5], Loss: 1.4452
# Client 3 Private Data Validation Accuracy: 49.33%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.0523
# Server KD distillation - Epoch [2/10], Loss: 0.0511
# Server KD distillation - Epoch [3/10], Loss: 0.0503
# Server KD distillation - Epoch [4/10], Loss: 0.0497
# Server KD distillation - Epoch [5/10], Loss: 0.0491
# Server KD distillation - Epoch [6/10], Loss: 0.0486
# Server KD distillation - Epoch [7/10], Loss: 0.0481
# Server KD distillation - Epoch [8/10], Loss: 0.0476
# Server KD distillation - Epoch [9/10], Loss: 0.0470
# Server KD distillation - Epoch [10/10], Loss: 0.0463
# Server Public Data Validation Accuracy: 13.82%
# Client 0 Public Data Validation Accuracy before distillation: 25.50%
# Client 1 Public Data Validation Accuracy before distillation: 25.98%
# Client 2 Public Data Validation Accuracy before distillation: 28.48%
# Client 3 Public Data Validation Accuracy before distillation: 33.66%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0222, Accuracy: 30.36%
# Client distillation update - Epoch [2/5], Loss: 0.0125, Accuracy: 30.82%
# Client distillation update - Epoch [3/5], Loss: 0.0102, Accuracy: 30.54%
# Client distillation update - Epoch [4/5], Loss: 0.0093, Accuracy: 30.56%
# Client distillation update - Epoch [5/5], Loss: 0.0083, Accuracy: 30.58%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0146, Accuracy: 30.02%
# Client distillation update - Epoch [2/5], Loss: 0.0078, Accuracy: 29.48%
# Client distillation update - Epoch [3/5], Loss: 0.0072, Accuracy: 29.68%
# Client distillation update - Epoch [4/5], Loss: 0.0068, Accuracy: 29.88%
# Client distillation update - Epoch [5/5], Loss: 0.0065, Accuracy: 30.26%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0189, Accuracy: 32.60%
# Client distillation update - Epoch [2/5], Loss: 0.0075, Accuracy: 32.04%
# Client distillation update - Epoch [3/5], Loss: 0.0068, Accuracy: 31.84%
# Client distillation update - Epoch [4/5], Loss: 0.0064, Accuracy: 31.94%
# Client distillation update - Epoch [5/5], Loss: 0.0062, Accuracy: 31.86%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0138, Accuracy: 37.26%
# Client distillation update - Epoch [2/5], Loss: 0.0075, Accuracy: 36.58%
# Client distillation update - Epoch [3/5], Loss: 0.0067, Accuracy: 36.06%
# Client distillation update - Epoch [4/5], Loss: 0.0062, Accuracy: 35.66%
# Client distillation update - Epoch [5/5], Loss: 0.0056, Accuracy: 35.66%
# ==================== COMM ROUND 2 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.5427
# Client local training - Epoch [2/5], Loss: 1.4758
# Client local training - Epoch [3/5], Loss: 1.4245
# Client local training - Epoch [4/5], Loss: 1.3855
# Client local training - Epoch [5/5], Loss: 1.3424
# Client 0 Private Data Validation Accuracy: 46.01%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.4086
# Client local training - Epoch [2/5], Loss: 1.3500
# Client local training - Epoch [3/5], Loss: 1.3135
# Client local training - Epoch [4/5], Loss: 1.2743
# Client local training - Epoch [5/5], Loss: 1.2540
# Client 1 Private Data Validation Accuracy: 37.28%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.3472
# Client local training - Epoch [2/5], Loss: 1.2840
# Client local training - Epoch [3/5], Loss: 1.2440
# Client local training - Epoch [4/5], Loss: 1.2093
# Client local training - Epoch [5/5], Loss: 1.1696
# Client 2 Private Data Validation Accuracy: 59.80%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.3855
# Client local training - Epoch [2/5], Loss: 1.3225
# Client local training - Epoch [3/5], Loss: 1.2741
# Client local training - Epoch [4/5], Loss: 1.2412
# Client local training - Epoch [5/5], Loss: 1.2075
# Client 3 Private Data Validation Accuracy: 56.35%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1060
# Server KD distillation - Epoch [2/10], Loss: 0.1019
# Server KD distillation - Epoch [3/10], Loss: 0.0988
# Server KD distillation - Epoch [4/10], Loss: 0.0956
# Server KD distillation - Epoch [5/10], Loss: 0.0920
# Server KD distillation - Epoch [6/10], Loss: 0.0877
# Server KD distillation - Epoch [7/10], Loss: 0.0828
# Server KD distillation - Epoch [8/10], Loss: 0.0775
# Server KD distillation - Epoch [9/10], Loss: 0.0729
# Server KD distillation - Epoch [10/10], Loss: 0.0684
# Server Public Data Validation Accuracy: 20.78%
# Client 0 Public Data Validation Accuracy before distillation: 39.58%
# Client 1 Public Data Validation Accuracy before distillation: 21.62%
# Client 2 Public Data Validation Accuracy before distillation: 34.94%
# Client 3 Public Data Validation Accuracy before distillation: 38.12%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0272, Accuracy: 37.74%
# Client distillation update - Epoch [2/5], Loss: 0.0173, Accuracy: 38.34%
# Client distillation update - Epoch [3/5], Loss: 0.0151, Accuracy: 38.28%
# Client distillation update - Epoch [4/5], Loss: 0.0142, Accuracy: 38.32%
# Client distillation update - Epoch [5/5], Loss: 0.0131, Accuracy: 38.48%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0206, Accuracy: 39.00%
# Client distillation update - Epoch [2/5], Loss: 0.0140, Accuracy: 39.04%
# Client distillation update - Epoch [3/5], Loss: 0.0128, Accuracy: 39.06%
# Client distillation update - Epoch [4/5], Loss: 0.0120, Accuracy: 39.28%
# Client distillation update - Epoch [5/5], Loss: 0.0117, Accuracy: 39.34%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0240, Accuracy: 37.86%
# Client distillation update - Epoch [2/5], Loss: 0.0136, Accuracy: 37.78%
# Client distillation update - Epoch [3/5], Loss: 0.0124, Accuracy: 37.62%
# Client distillation update - Epoch [4/5], Loss: 0.0118, Accuracy: 37.96%
# Client distillation update - Epoch [5/5], Loss: 0.0111, Accuracy: 38.00%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0182, Accuracy: 44.88%
# Client distillation update - Epoch [2/5], Loss: 0.0110, Accuracy: 44.34%
# Client distillation update - Epoch [3/5], Loss: 0.0099, Accuracy: 43.52%
# Client distillation update - Epoch [4/5], Loss: 0.0096, Accuracy: 43.66%
# Client distillation update - Epoch [5/5], Loss: 0.0092, Accuracy: 43.38%
# ==================== COMM ROUND 3 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.3265
# Client local training - Epoch [2/5], Loss: 1.2788
# Client local training - Epoch [3/5], Loss: 1.2573
# Client local training - Epoch [4/5], Loss: 1.2251
# Client local training - Epoch [5/5], Loss: 1.1952
# Client 0 Private Data Validation Accuracy: 51.40%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.2217
# Client local training - Epoch [2/5], Loss: 1.1918
# Client local training - Epoch [3/5], Loss: 1.1716
# Client local training - Epoch [4/5], Loss: 1.1423
# Client local training - Epoch [5/5], Loss: 1.1191
# Client 1 Private Data Validation Accuracy: 57.16%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1580
# Client local training - Epoch [2/5], Loss: 1.1070
# Client local training - Epoch [3/5], Loss: 1.0869
# Client local training - Epoch [4/5], Loss: 1.0671
# Client local training - Epoch [5/5], Loss: 1.0392
# Client 2 Private Data Validation Accuracy: 62.69%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1798
# Client local training - Epoch [2/5], Loss: 1.1449
# Client local training - Epoch [3/5], Loss: 1.1208
# Client local training - Epoch [4/5], Loss: 1.0888
# Client local training - Epoch [5/5], Loss: 1.0672
# Client 3 Private Data Validation Accuracy: 61.30%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1076
# Server KD distillation - Epoch [2/10], Loss: 0.1006
# Server KD distillation - Epoch [3/10], Loss: 0.0955
# Server KD distillation - Epoch [4/10], Loss: 0.0906
# Server KD distillation - Epoch [5/10], Loss: 0.0869
# Server KD distillation - Epoch [6/10], Loss: 0.0830
# Server KD distillation - Epoch [7/10], Loss: 0.0802
# Server KD distillation - Epoch [8/10], Loss: 0.0777
# Server KD distillation - Epoch [9/10], Loss: 0.0762
# Server KD distillation - Epoch [10/10], Loss: 0.0744
# Server Public Data Validation Accuracy: 24.52%
# Client 0 Public Data Validation Accuracy before distillation: 39.06%
# Client 1 Public Data Validation Accuracy before distillation: 36.64%
# Client 2 Public Data Validation Accuracy before distillation: 38.32%
# Client 3 Public Data Validation Accuracy before distillation: 47.08%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0283, Accuracy: 44.02%
# Client distillation update - Epoch [2/5], Loss: 0.0199, Accuracy: 44.00%
# Client distillation update - Epoch [3/5], Loss: 0.0182, Accuracy: 43.96%
# Client distillation update - Epoch [4/5], Loss: 0.0172, Accuracy: 44.14%
# Client distillation update - Epoch [5/5], Loss: 0.0164, Accuracy: 44.32%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0220, Accuracy: 44.80%
# Client distillation update - Epoch [2/5], Loss: 0.0168, Accuracy: 45.26%
# Client distillation update - Epoch [3/5], Loss: 0.0155, Accuracy: 45.32%
# Client distillation update - Epoch [4/5], Loss: 0.0146, Accuracy: 45.70%
# Client distillation update - Epoch [5/5], Loss: 0.0145, Accuracy: 45.52%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0282, Accuracy: 42.86%
# Client distillation update - Epoch [2/5], Loss: 0.0173, Accuracy: 42.98%
# Client distillation update - Epoch [3/5], Loss: 0.0160, Accuracy: 43.26%
# Client distillation update - Epoch [4/5], Loss: 0.0147, Accuracy: 43.18%
# Client distillation update - Epoch [5/5], Loss: 0.0141, Accuracy: 43.56%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0195, Accuracy: 49.24%
# Client distillation update - Epoch [2/5], Loss: 0.0141, Accuracy: 49.08%
# Client distillation update - Epoch [3/5], Loss: 0.0129, Accuracy: 48.26%
# Client distillation update - Epoch [4/5], Loss: 0.0120, Accuracy: 47.98%
# Client distillation update - Epoch [5/5], Loss: 0.0119, Accuracy: 47.90%
# ==================== COMM ROUND 4 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.1824
# Client local training - Epoch [2/5], Loss: 1.1487
# Client local training - Epoch [3/5], Loss: 1.1248
# Client local training - Epoch [4/5], Loss: 1.0989
# Client local training - Epoch [5/5], Loss: 1.0754
# Client 0 Private Data Validation Accuracy: 50.26%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0965
# Client local training - Epoch [2/5], Loss: 1.0773
# Client local training - Epoch [3/5], Loss: 1.0420
# Client local training - Epoch [4/5], Loss: 1.0254
# Client local training - Epoch [5/5], Loss: 0.9910
# Client 1 Private Data Validation Accuracy: 54.88%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0220
# Client local training - Epoch [2/5], Loss: 0.9991
# Client local training - Epoch [3/5], Loss: 0.9610
# Client local training - Epoch [4/5], Loss: 0.9414
# Client local training - Epoch [5/5], Loss: 0.9150
# Client 2 Private Data Validation Accuracy: 65.92%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0458
# Client local training - Epoch [2/5], Loss: 1.0190
# Client local training - Epoch [3/5], Loss: 0.9957
# Client local training - Epoch [4/5], Loss: 0.9758
# Client local training - Epoch [5/5], Loss: 0.9537
# Client 3 Private Data Validation Accuracy: 63.71%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1129
# Server KD distillation - Epoch [2/10], Loss: 0.1090
# Server KD distillation - Epoch [3/10], Loss: 0.1062
# Server KD distillation - Epoch [4/10], Loss: 0.1027
# Server KD distillation - Epoch [5/10], Loss: 0.1000
# Server KD distillation - Epoch [6/10], Loss: 0.0972
# Server KD distillation - Epoch [7/10], Loss: 0.0943
# Server KD distillation - Epoch [8/10], Loss: 0.0911
# Server KD distillation - Epoch [9/10], Loss: 0.0883
# Server KD distillation - Epoch [10/10], Loss: 0.0858
# Server Public Data Validation Accuracy: 28.72%
# Client 0 Public Data Validation Accuracy before distillation: 45.66%
# Client 1 Public Data Validation Accuracy before distillation: 33.40%
# Client 2 Public Data Validation Accuracy before distillation: 43.36%
# Client 3 Public Data Validation Accuracy before distillation: 50.58%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0322, Accuracy: 47.32%
# Client distillation update - Epoch [2/5], Loss: 0.0255, Accuracy: 47.28%
# Client distillation update - Epoch [3/5], Loss: 0.0240, Accuracy: 47.44%
# Client distillation update - Epoch [4/5], Loss: 0.0225, Accuracy: 47.32%
# Client distillation update - Epoch [5/5], Loss: 0.0208, Accuracy: 47.48%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0270, Accuracy: 48.36%
# Client distillation update - Epoch [2/5], Loss: 0.0214, Accuracy: 48.74%
# Client distillation update - Epoch [3/5], Loss: 0.0201, Accuracy: 48.96%
# Client distillation update - Epoch [4/5], Loss: 0.0194, Accuracy: 49.18%
# Client distillation update - Epoch [5/5], Loss: 0.0190, Accuracy: 49.14%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0321, Accuracy: 47.64%
# Client distillation update - Epoch [2/5], Loss: 0.0217, Accuracy: 47.88%
# Client distillation update - Epoch [3/5], Loss: 0.0200, Accuracy: 48.06%
# Client distillation update - Epoch [4/5], Loss: 0.0189, Accuracy: 48.16%
# Client distillation update - Epoch [5/5], Loss: 0.0180, Accuracy: 48.30%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0246, Accuracy: 53.86%
# Client distillation update - Epoch [2/5], Loss: 0.0191, Accuracy: 53.36%
# Client distillation update - Epoch [3/5], Loss: 0.0177, Accuracy: 52.76%
# Client distillation update - Epoch [4/5], Loss: 0.0168, Accuracy: 52.16%
# Client distillation update - Epoch [5/5], Loss: 0.0162, Accuracy: 52.04%
# ==================== COMM ROUND 5 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 1.0474
# Client local training - Epoch [2/5], Loss: 1.0270
# Client local training - Epoch [3/5], Loss: 1.0013
# Client local training - Epoch [4/5], Loss: 0.9908
# Client local training - Epoch [5/5], Loss: 0.9535
# Client 0 Private Data Validation Accuracy: 55.04%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9906
# Client local training - Epoch [2/5], Loss: 0.9551
# Client local training - Epoch [3/5], Loss: 0.9235
# Client local training - Epoch [4/5], Loss: 0.9040
# Client local training - Epoch [5/5], Loss: 0.8875
# Client 1 Private Data Validation Accuracy: 62.96%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8958
# Client local training - Epoch [2/5], Loss: 0.8715
# Client local training - Epoch [3/5], Loss: 0.8487
# Client local training - Epoch [4/5], Loss: 0.8191
# Client local training - Epoch [5/5], Loss: 0.8062
# Client 2 Private Data Validation Accuracy: 64.25%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9335
# Client local training - Epoch [2/5], Loss: 0.9079
# Client local training - Epoch [3/5], Loss: 0.8880
# Client local training - Epoch [4/5], Loss: 0.8622
# Client local training - Epoch [5/5], Loss: 0.8383
# Client 3 Private Data Validation Accuracy: 66.13%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1077
# Server KD distillation - Epoch [2/10], Loss: 0.1037
# Server KD distillation - Epoch [3/10], Loss: 0.0999
# Server KD distillation - Epoch [4/10], Loss: 0.0963
# Server KD distillation - Epoch [5/10], Loss: 0.0934
# Server KD distillation - Epoch [6/10], Loss: 0.0891
# Server KD distillation - Epoch [7/10], Loss: 0.0861
# Server KD distillation - Epoch [8/10], Loss: 0.0838
# Server KD distillation - Epoch [9/10], Loss: 0.0806
# Server KD distillation - Epoch [10/10], Loss: 0.0779
# Server Public Data Validation Accuracy: 31.92%
# Client 0 Public Data Validation Accuracy before distillation: 43.84%
# Client 1 Public Data Validation Accuracy before distillation: 42.26%
# Client 2 Public Data Validation Accuracy before distillation: 40.16%
# Client 3 Public Data Validation Accuracy before distillation: 52.56%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0389, Accuracy: 50.44%
# Client distillation update - Epoch [2/5], Loss: 0.0297, Accuracy: 51.08%
# Client distillation update - Epoch [3/5], Loss: 0.0268, Accuracy: 51.40%
# Client distillation update - Epoch [4/5], Loss: 0.0256, Accuracy: 51.44%
# Client distillation update - Epoch [5/5], Loss: 0.0243, Accuracy: 51.20%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0292, Accuracy: 50.42%
# Client distillation update - Epoch [2/5], Loss: 0.0246, Accuracy: 50.82%
# Client distillation update - Epoch [3/5], Loss: 0.0231, Accuracy: 50.96%
# Client distillation update - Epoch [4/5], Loss: 0.0216, Accuracy: 51.08%
# Client distillation update - Epoch [5/5], Loss: 0.0210, Accuracy: 51.22%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0333, Accuracy: 49.18%
# Client distillation update - Epoch [2/5], Loss: 0.0235, Accuracy: 49.62%
# Client distillation update - Epoch [3/5], Loss: 0.0224, Accuracy: 49.54%
# Client distillation update - Epoch [4/5], Loss: 0.0210, Accuracy: 49.60%
# Client distillation update - Epoch [5/5], Loss: 0.0199, Accuracy: 50.06%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0285, Accuracy: 55.40%
# Client distillation update - Epoch [2/5], Loss: 0.0213, Accuracy: 54.66%
# Client distillation update - Epoch [3/5], Loss: 0.0203, Accuracy: 54.72%
# Client distillation update - Epoch [4/5], Loss: 0.0195, Accuracy: 54.34%
# Client distillation update - Epoch [5/5], Loss: 0.0185, Accuracy: 54.14%
# ==================== COMM ROUND 6 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.9264
# Client local training - Epoch [2/5], Loss: 0.9080
# Client local training - Epoch [3/5], Loss: 0.8828
# Client local training - Epoch [4/5], Loss: 0.8613
# Client local training - Epoch [5/5], Loss: 0.8302
# Client 0 Private Data Validation Accuracy: 55.43%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8575
# Client local training - Epoch [2/5], Loss: 0.8339
# Client local training - Epoch [3/5], Loss: 0.8244
# Client local training - Epoch [4/5], Loss: 0.7893
# Client local training - Epoch [5/5], Loss: 0.7627
# Client 1 Private Data Validation Accuracy: 62.57%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.7790
# Client local training - Epoch [2/5], Loss: 0.7605
# Client local training - Epoch [3/5], Loss: 0.7358
# Client local training - Epoch [4/5], Loss: 0.7238
# Client local training - Epoch [5/5], Loss: 0.6937
# Client 2 Private Data Validation Accuracy: 69.88%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8272
# Client local training - Epoch [2/5], Loss: 0.7927
# Client local training - Epoch [3/5], Loss: 0.7791
# Client local training - Epoch [4/5], Loss: 0.7464
# Client local training - Epoch [5/5], Loss: 0.7232
# Client 3 Private Data Validation Accuracy: 67.86%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1155
# Server KD distillation - Epoch [2/10], Loss: 0.1101
# Server KD distillation - Epoch [3/10], Loss: 0.1061
# Server KD distillation - Epoch [4/10], Loss: 0.1037
# Server KD distillation - Epoch [5/10], Loss: 0.1003
# Server KD distillation - Epoch [6/10], Loss: 0.0971
# Server KD distillation - Epoch [7/10], Loss: 0.0939
# Server KD distillation - Epoch [8/10], Loss: 0.0916
# Server KD distillation - Epoch [9/10], Loss: 0.0888
# Server KD distillation - Epoch [10/10], Loss: 0.0864
# Server Public Data Validation Accuracy: 37.32%
# Client 0 Public Data Validation Accuracy before distillation: 47.34%
# Client 1 Public Data Validation Accuracy before distillation: 40.16%
# Client 2 Public Data Validation Accuracy before distillation: 47.54%
# Client 3 Public Data Validation Accuracy before distillation: 53.50%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0454, Accuracy: 52.12%
# Client distillation update - Epoch [2/5], Loss: 0.0383, Accuracy: 53.68%
# Client distillation update - Epoch [3/5], Loss: 0.0357, Accuracy: 53.52%
# Client distillation update - Epoch [4/5], Loss: 0.0328, Accuracy: 53.68%
# Client distillation update - Epoch [5/5], Loss: 0.0317, Accuracy: 53.94%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0402, Accuracy: 54.00%
# Client distillation update - Epoch [2/5], Loss: 0.0335, Accuracy: 54.54%
# Client distillation update - Epoch [3/5], Loss: 0.0316, Accuracy: 54.38%
# Client distillation update - Epoch [4/5], Loss: 0.0302, Accuracy: 54.40%
# Client distillation update - Epoch [5/5], Loss: 0.0282, Accuracy: 54.62%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0431, Accuracy: 52.18%
# Client distillation update - Epoch [2/5], Loss: 0.0318, Accuracy: 52.28%
# Client distillation update - Epoch [3/5], Loss: 0.0298, Accuracy: 52.48%
# Client distillation update - Epoch [4/5], Loss: 0.0286, Accuracy: 52.58%
# Client distillation update - Epoch [5/5], Loss: 0.0270, Accuracy: 52.74%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0365, Accuracy: 58.30%
# Client distillation update - Epoch [2/5], Loss: 0.0296, Accuracy: 58.06%
# Client distillation update - Epoch [3/5], Loss: 0.0275, Accuracy: 57.86%
# Client distillation update - Epoch [4/5], Loss: 0.0263, Accuracy: 57.40%
# Client distillation update - Epoch [5/5], Loss: 0.0252, Accuracy: 57.70%
# ==================== COMM ROUND 7 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.8060
# Client local training - Epoch [2/5], Loss: 0.7714
# Client local training - Epoch [3/5], Loss: 0.7514
# Client local training - Epoch [4/5], Loss: 0.7223
# Client local training - Epoch [5/5], Loss: 0.6900
# Client 0 Private Data Validation Accuracy: 58.28%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.7468
# Client local training - Epoch [2/5], Loss: 0.7118
# Client local training - Epoch [3/5], Loss: 0.6995
# Client local training - Epoch [4/5], Loss: 0.6794
# Client local training - Epoch [5/5], Loss: 0.6557
# Client 1 Private Data Validation Accuracy: 66.30%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.6728
# Client local training - Epoch [2/5], Loss: 0.6538
# Client local training - Epoch [3/5], Loss: 0.6287
# Client local training - Epoch [4/5], Loss: 0.6006
# Client local training - Epoch [5/5], Loss: 0.5903
# Client 2 Private Data Validation Accuracy: 70.90%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.7093
# Client local training - Epoch [2/5], Loss: 0.6830
# Client local training - Epoch [3/5], Loss: 0.6613
# Client local training - Epoch [4/5], Loss: 0.6354
# Client local training - Epoch [5/5], Loss: 0.6084
# Client 3 Private Data Validation Accuracy: 68.58%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1215
# Server KD distillation - Epoch [2/10], Loss: 0.1179
# Server KD distillation - Epoch [3/10], Loss: 0.1142
# Server KD distillation - Epoch [4/10], Loss: 0.1117
# Server KD distillation - Epoch [5/10], Loss: 0.1078
# Server KD distillation - Epoch [6/10], Loss: 0.1059
# Server KD distillation - Epoch [7/10], Loss: 0.1045
# Server KD distillation - Epoch [8/10], Loss: 0.1021
# Server KD distillation - Epoch [9/10], Loss: 0.0989
# Server KD distillation - Epoch [10/10], Loss: 0.0963
# Server Public Data Validation Accuracy: 37.22%
# Client 0 Public Data Validation Accuracy before distillation: 48.10%
# Client 1 Public Data Validation Accuracy before distillation: 49.62%
# Client 2 Public Data Validation Accuracy before distillation: 50.00%
# Client 3 Public Data Validation Accuracy before distillation: 59.42%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0553, Accuracy: 55.78%
# Client distillation update - Epoch [2/5], Loss: 0.0466, Accuracy: 55.92%
# Client distillation update - Epoch [3/5], Loss: 0.0433, Accuracy: 55.98%
# Client distillation update - Epoch [4/5], Loss: 0.0409, Accuracy: 56.34%
# Client distillation update - Epoch [5/5], Loss: 0.0385, Accuracy: 56.96%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0485, Accuracy: 56.80%
# Client distillation update - Epoch [2/5], Loss: 0.0432, Accuracy: 57.20%
# Client distillation update - Epoch [3/5], Loss: 0.0392, Accuracy: 57.42%
# Client distillation update - Epoch [4/5], Loss: 0.0377, Accuracy: 57.72%
# Client distillation update - Epoch [5/5], Loss: 0.0358, Accuracy: 57.48%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0503, Accuracy: 53.74%
# Client distillation update - Epoch [2/5], Loss: 0.0395, Accuracy: 54.14%
# Client distillation update - Epoch [3/5], Loss: 0.0371, Accuracy: 54.30%
# Client distillation update - Epoch [4/5], Loss: 0.0349, Accuracy: 54.46%
# Client distillation update - Epoch [5/5], Loss: 0.0334, Accuracy: 54.58%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0464, Accuracy: 60.14%
# Client distillation update - Epoch [2/5], Loss: 0.0375, Accuracy: 60.02%
# Client distillation update - Epoch [3/5], Loss: 0.0343, Accuracy: 60.08%
# Client distillation update - Epoch [4/5], Loss: 0.0329, Accuracy: 60.06%
# Client distillation update - Epoch [5/5], Loss: 0.0317, Accuracy: 59.94%
# ==================== COMM ROUND 8 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.6773
# Client local training - Epoch [2/5], Loss: 0.6423
# Client local training - Epoch [3/5], Loss: 0.6061
# Client local training - Epoch [4/5], Loss: 0.5716
# Client local training - Epoch [5/5], Loss: 0.5456
# Client 0 Private Data Validation Accuracy: 54.08%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.6227
# Client local training - Epoch [2/5], Loss: 0.6084
# Client local training - Epoch [3/5], Loss: 0.5868
# Client local training - Epoch [4/5], Loss: 0.5649
# Client local training - Epoch [5/5], Loss: 0.5340
# Client 1 Private Data Validation Accuracy: 66.10%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.5787
# Client local training - Epoch [2/5], Loss: 0.5524
# Client local training - Epoch [3/5], Loss: 0.5386
# Client local training - Epoch [4/5], Loss: 0.5111
# Client local training - Epoch [5/5], Loss: 0.4806
# Client 2 Private Data Validation Accuracy: 70.86%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.5895
# Client local training - Epoch [2/5], Loss: 0.5665
# Client local training - Epoch [3/5], Loss: 0.5362
# Client local training - Epoch [4/5], Loss: 0.5159
# Client local training - Epoch [5/5], Loss: 0.4864
# Client 3 Private Data Validation Accuracy: 69.81%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1419
# Server KD distillation - Epoch [2/10], Loss: 0.1367
# Server KD distillation - Epoch [3/10], Loss: 0.1322
# Server KD distillation - Epoch [4/10], Loss: 0.1294
# Server KD distillation - Epoch [5/10], Loss: 0.1268
# Server KD distillation - Epoch [6/10], Loss: 0.1241
# Server KD distillation - Epoch [7/10], Loss: 0.1209
# Server KD distillation - Epoch [8/10], Loss: 0.1192
# Server KD distillation - Epoch [9/10], Loss: 0.1166
# Server KD distillation - Epoch [10/10], Loss: 0.1131
# Server Public Data Validation Accuracy: 41.16%
# Client 0 Public Data Validation Accuracy before distillation: 50.96%
# Client 1 Public Data Validation Accuracy before distillation: 49.94%
# Client 2 Public Data Validation Accuracy before distillation: 50.16%
# Client 3 Public Data Validation Accuracy before distillation: 57.48%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0695, Accuracy: 55.54%
# Client distillation update - Epoch [2/5], Loss: 0.0583, Accuracy: 56.84%
# Client distillation update - Epoch [3/5], Loss: 0.0541, Accuracy: 57.06%
# Client distillation update - Epoch [4/5], Loss: 0.0512, Accuracy: 57.54%
# Client distillation update - Epoch [5/5], Loss: 0.0491, Accuracy: 57.12%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0636, Accuracy: 57.54%
# Client distillation update - Epoch [2/5], Loss: 0.0543, Accuracy: 58.32%
# Client distillation update - Epoch [3/5], Loss: 0.0510, Accuracy: 58.38%
# Client distillation update - Epoch [4/5], Loss: 0.0484, Accuracy: 57.98%
# Client distillation update - Epoch [5/5], Loss: 0.0461, Accuracy: 58.38%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0598, Accuracy: 55.50%
# Client distillation update - Epoch [2/5], Loss: 0.0496, Accuracy: 55.60%
# Client distillation update - Epoch [3/5], Loss: 0.0459, Accuracy: 55.70%
# Client distillation update - Epoch [4/5], Loss: 0.0428, Accuracy: 55.74%
# Client distillation update - Epoch [5/5], Loss: 0.0409, Accuracy: 55.48%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0585, Accuracy: 61.12%
# Client distillation update - Epoch [2/5], Loss: 0.0486, Accuracy: 61.00%
# Client distillation update - Epoch [3/5], Loss: 0.0450, Accuracy: 61.04%
# Client distillation update - Epoch [4/5], Loss: 0.0424, Accuracy: 60.82%
# Client distillation update - Epoch [5/5], Loss: 0.0402, Accuracy: 61.16%
# ==================== COMM ROUND 9 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.5226
# Client local training - Epoch [2/5], Loss: 0.4943
# Client local training - Epoch [3/5], Loss: 0.4679
# Client local training - Epoch [4/5], Loss: 0.4390
# Client local training - Epoch [5/5], Loss: 0.4114
# Client 0 Private Data Validation Accuracy: 57.67%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.5198
# Client local training - Epoch [2/5], Loss: 0.4857
# Client local training - Epoch [3/5], Loss: 0.4677
# Client local training - Epoch [4/5], Loss: 0.4536
# Client local training - Epoch [5/5], Loss: 0.4277
# Client 1 Private Data Validation Accuracy: 68.04%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.4730
# Client local training - Epoch [2/5], Loss: 0.4479
# Client local training - Epoch [3/5], Loss: 0.4308
# Client local training - Epoch [4/5], Loss: 0.4061
# Client local training - Epoch [5/5], Loss: 0.3862
# Client 2 Private Data Validation Accuracy: 74.03%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.4673
# Client local training - Epoch [2/5], Loss: 0.4411
# Client local training - Epoch [3/5], Loss: 0.4132
# Client local training - Epoch [4/5], Loss: 0.3946
# Client local training - Epoch [5/5], Loss: 0.3687
# Client 3 Private Data Validation Accuracy: 69.58%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1702
# Server KD distillation - Epoch [2/10], Loss: 0.1643
# Server KD distillation - Epoch [3/10], Loss: 0.1584
# Server KD distillation - Epoch [4/10], Loss: 0.1539
# Server KD distillation - Epoch [5/10], Loss: 0.1515
# Server KD distillation - Epoch [6/10], Loss: 0.1484
# Server KD distillation - Epoch [7/10], Loss: 0.1453
# Server KD distillation - Epoch [8/10], Loss: 0.1422
# Server KD distillation - Epoch [9/10], Loss: 0.1393
# Server KD distillation - Epoch [10/10], Loss: 0.1367
# Server Public Data Validation Accuracy: 40.92%
# Client 0 Public Data Validation Accuracy before distillation: 52.14%
# Client 1 Public Data Validation Accuracy before distillation: 54.20%
# Client 2 Public Data Validation Accuracy before distillation: 51.08%
# Client 3 Public Data Validation Accuracy before distillation: 60.64%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0876, Accuracy: 56.98%
# Client distillation update - Epoch [2/5], Loss: 0.0742, Accuracy: 58.26%
# Client distillation update - Epoch [3/5], Loss: 0.0674, Accuracy: 58.30%
# Client distillation update - Epoch [4/5], Loss: 0.0640, Accuracy: 58.44%
# Client distillation update - Epoch [5/5], Loss: 0.0617, Accuracy: 58.30%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0810, Accuracy: 59.02%
# Client distillation update - Epoch [2/5], Loss: 0.0698, Accuracy: 58.82%
# Client distillation update - Epoch [3/5], Loss: 0.0640, Accuracy: 59.30%
# Client distillation update - Epoch [4/5], Loss: 0.0623, Accuracy: 58.74%
# Client distillation update - Epoch [5/5], Loss: 0.0585, Accuracy: 60.22%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0749, Accuracy: 55.30%
# Client distillation update - Epoch [2/5], Loss: 0.0624, Accuracy: 55.58%
# Client distillation update - Epoch [3/5], Loss: 0.0570, Accuracy: 55.98%
# Client distillation update - Epoch [4/5], Loss: 0.0544, Accuracy: 56.76%
# Client distillation update - Epoch [5/5], Loss: 0.0519, Accuracy: 56.94%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0762, Accuracy: 61.22%
# Client distillation update - Epoch [2/5], Loss: 0.0611, Accuracy: 60.70%
# Client distillation update - Epoch [3/5], Loss: 0.0577, Accuracy: 61.12%
# Client distillation update - Epoch [4/5], Loss: 0.0534, Accuracy: 60.60%
# Client distillation update - Epoch [5/5], Loss: 0.0513, Accuracy: 60.98%
# ==================== COMM ROUND 10 ====================
#
# --- LOCAL TRAINING OF CLIENTS ---
#
# --- Client 0 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.3831
# Client local training - Epoch [2/5], Loss: 0.3643
# Client local training - Epoch [3/5], Loss: 0.3229
# Client local training - Epoch [4/5], Loss: 0.3022
# Client local training - Epoch [5/5], Loss: 0.2815
# Client 0 Private Data Validation Accuracy: 57.98%
#
# --- Client 1 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.4055
# Client local training - Epoch [2/5], Loss: 0.3845
# Client local training - Epoch [3/5], Loss: 0.3551
# Client local training - Epoch [4/5], Loss: 0.3485
# Client local training - Epoch [5/5], Loss: 0.3135
# Client 1 Private Data Validation Accuracy: 68.38%
#
# --- Client 2 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.3724
# Client local training - Epoch [2/5], Loss: 0.3489
# Client local training - Epoch [3/5], Loss: 0.3187
# Client local training - Epoch [4/5], Loss: 0.2992
# Client local training - Epoch [5/5], Loss: 0.2936
# Client 2 Private Data Validation Accuracy: 71.49%
#
# --- Client 3 Local Training ---
# Client local training - Epoch [1/5], Loss: 0.3614
# Client local training - Epoch [2/5], Loss: 0.3386
# Client local training - Epoch [3/5], Loss: 0.2989
# Client local training - Epoch [4/5], Loss: 0.2797
# Client local training - Epoch [5/5], Loss: 0.2683
# Client 3 Private Data Validation Accuracy: 71.38%
#
# --- Client 0 Generating Logits on Public Data ---
#
# --- Client 1 Generating Logits on Public Data ---
#
# --- Client 2 Generating Logits on Public Data ---
#
# --- Client 3 Generating Logits on Public Data ---
#
# --- Server KD Distillation Update ---
# Server KD distillation - Epoch [1/10], Loss: 0.1988
# Server KD distillation - Epoch [2/10], Loss: 0.1899
# Server KD distillation - Epoch [3/10], Loss: 0.1841
# Server KD distillation - Epoch [4/10], Loss: 0.1810
# Server KD distillation - Epoch [5/10], Loss: 0.1764
# Server KD distillation - Epoch [6/10], Loss: 0.1731
# Server KD distillation - Epoch [7/10], Loss: 0.1667
# Server KD distillation - Epoch [8/10], Loss: 0.1649
# Server KD distillation - Epoch [9/10], Loss: 0.1623
# Server KD distillation - Epoch [10/10], Loss: 0.1577
# Server Public Data Validation Accuracy: 43.44%
# Client 0 Public Data Validation Accuracy before distillation: 47.70%
# Client 1 Public Data Validation Accuracy before distillation: 50.46%
# Client 2 Public Data Validation Accuracy before distillation: 50.50%
# Client 3 Public Data Validation Accuracy before distillation: 58.72%
#
# --- Client 0 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1104, Accuracy: 56.94%
# Client distillation update - Epoch [2/5], Loss: 0.0915, Accuracy: 58.22%
# Client distillation update - Epoch [3/5], Loss: 0.0837, Accuracy: 58.38%
# Client distillation update - Epoch [4/5], Loss: 0.0784, Accuracy: 59.02%
# Client distillation update - Epoch [5/5], Loss: 0.0739, Accuracy: 58.96%
#
# --- Client 1 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.1026, Accuracy: 60.06%
# Client distillation update - Epoch [2/5], Loss: 0.0864, Accuracy: 59.96%
# Client distillation update - Epoch [3/5], Loss: 0.0799, Accuracy: 60.34%
# Client distillation update - Epoch [4/5], Loss: 0.0757, Accuracy: 60.66%
# Client distillation update - Epoch [5/5], Loss: 0.0723, Accuracy: 60.68%
#
# --- Client 2 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0958, Accuracy: 55.98%
# Client distillation update - Epoch [2/5], Loss: 0.0780, Accuracy: 57.28%
# Client distillation update - Epoch [3/5], Loss: 0.0718, Accuracy: 56.94%
# Client distillation update - Epoch [4/5], Loss: 0.0681, Accuracy: 57.28%
# Client distillation update - Epoch [5/5], Loss: 0.0661, Accuracy: 56.74%
#
# --- Client 3 Distillation Update ---
# Client distillation update - Epoch [1/5], Loss: 0.0957, Accuracy: 61.32%
# Client distillation update - Epoch [2/5], Loss: 0.0778, Accuracy: 60.78%
# Client distillation update - Epoch [3/5], Loss: 0.0706, Accuracy: 61.34%
# Client distillation update - Epoch [4/5], Loss: 0.0668, Accuracy: 61.66%
# Client distillation update - Epoch [5/5], Loss: 0.0635, Accuracy: 61.08%
# --- Clients Final Evaluation on Private Data sets ---
#
# --- Client 0 Evaluation ---
# Client 0 Final Private Data Validation Accuracy: 58.11%
#
# --- Client 1 Evaluation ---
# Client 1 Final Private Data Validation Accuracy: 64.41%
#
# --- Client 2 Evaluation ---
# Client 2 Final Private Data Validation Accuracy: 68.51%
#
# --- Client 3 Evaluation ---
# Client 3 Final Private Data Validation Accuracy: 60.38%
#
# Final Server Test Accuracy (on Public test_set): 43.88%

# %% [markdown]
# # Results

# %% [markdown]
# ---

# %% [markdown]
# | Metric                                               | Baseline Model         (T_soft = 1)         | Improvement 1 Model            |
# |------------------------------------------------------|----------------------------------|--------------------------------|
# | **Client 0 - Public Validation Accuracy**             | 52.58%                           | 58.96%                         |
# | **Client 1 - Public Validation Accuracy**             | 51.46%                           | 60.68%                         |
# | **Client 2 - Public Validation Accuracy**             | 50.74%                           | 56.74%                         |
# | **Client 3 - Public Validation Accuracy**             | 52.64%                           | 61.08%                         |
# | **Client 0 - Private Data Accuracy**                 | 51.71%                           | 58.11%                         |
# | **Client 1 - Private Data Accuracy**                 | 51.69%                           | 64.41%                         |
# | **Client 2 - Private Data Accuracy**                 | 60.29%                           | 68.51%                         |
# | **Client 3 - Private Data Accuracy**                 | 52.63%                           | 60.38%                         |
# | **Final Server Test Accuracy (on Public Test-Set)**  | 46.75%                           | 43.88%                         |

# %% [markdown]
# **Note:** Temps calculated via respective heterogneity scores of clients. Lower temp corresponds to a higher heterogeneity score.
#
# Client 0 T_soft: 0.2892
#
# Client 1 T_soft: 0.3038
#
# Client 2 T_soft: 0.3477
#
# Client 3 T_soft: 0.3424

# %% [markdown]
# ---

# %% [markdown]
# ## Rationale for Model Improvement 1
#
# In the baseline federated learning pipeline, clients experienced suboptimal local validation accuracies, which limited the effectiveness of global model distillation and aggregation. To address this, we propose a unique take on the **logit chilling** technique, adapted from the *FLex&Chill framework. This method applies a softmax temperature *T* between 0 and 1 during local training to sharpen output distributions and amplify confident predictions. The other innovative angle of our approach is that the original paper applies this technique to an FL based setting, whereas we propose to leverage it for a bidirectional federated k.d pipeline, which is something that isn't found in contemporary literature.
#
# *"Lower softmax temperatures help propagate stronger gradients to earlier network layers, enabling more effective representation learning—especially under non-i.i.d. client data conditions. Empirical studies have shown that using chilled logits can accelerate model convergence by up to 6× and improve inference accuracy by up to 3.37% compared to standard training with *T* = 1. Additionally, experiments across datasets such as FEMNIST-DNN, CIFAR10-CNN, and CIFAR100-ResNet18 demonstrated consistent gains in average client-side accuracy when using *T* < 1 during local training." ~ Lee et al.*
#
# Building on these findings, we implemented a **curriculum-based** personalized learning mechanism based on each client’s data heterogeneity. Each client chills its logits according to its class distribution divergence, ensuring adaptive training aligned with local data characteristics. This dynamic approach also supports stable convergence and better accommodates heterogeneous data settings as in our case.
#
# In our experiments, this personalized logit chilling strategy led to notable improvements in the accuracies on the local-training data across clients, which outperformed the baseline implementation significantly. Overall, integrating logit chilling into Model Improvement 1 leverages theoretical insights and proven empirical benefits to overcome baseline limitations and boost federated learning performance.
#
# (please see section below for citation information)

# %% [markdown]
# ## Building on the Framework; Motivation for Second Improvement
#
# -  One challenge that emerged from this model improvement was a **decrease in public data accuracy for the server model**, despite the fact that client models became more accurate. Specifically, we observed an average **drop of 3% in server model accuracy** on the public dataset. This indicates that while clients benefited from sharper local predictions (which is essential for making the learning at server-side more comprehensive and inclusive of the precise details encountered at each clients end), the global model may not have been learning as effectively from the aggregated updates. We shall investigate why this is happening in our second improvemnet, but we have strong theoretical evidence that supports the idea that this "adaptive logit-chilling" should benefit both the clients (which it is greatly right now), but the server as well. This is because sharper (low‐entropy) logits concentrate probability mass on the correct class, providing a stronger learning signal that emphasizes the most important decision boundaries. This helps the global model learn precise distinctions that might otherwise be washed out by overly soft targets. So aggregating these detailed, confident outputs yields a richer supervisory signal for the server, improving its performance on a balanced proxy set and enhancing its robustness to class‐imbalance drift. In our second iteration, we aim to address this by improving server model generalization so it performs better on public data set and can actually take advantage of the improved client models.
#
# -  **Why personalised approach?** Why did we use heterogeneity to scale temperatures and make learning personalised? Why didn't we instead use a fixed temperature score during logit chilling phase of our pipeline? In the FLex&Chill framework: it is stated that in iid settings using lower temperatures does not make much of a difference, but it actually works better in a non iid setting. The authors were using a fixed temperature for logit chilling whereas we have kept our adaptive, the reason for that is if some proportion of our clients had partitions which were iid, then using a very low temperature could have hindered the learning of our global server model and logit chilling wouldn't have had any effect on our results, whereas in our current pipeline, if any client does supposedly get an iid partition, then our personalised temperature scheduling automatically accounts for this and assigns a temperature closer to 1 for such a client during its local training phase (on its private data). This will be investigated further as well, but our claim is our curriculum based learning approach will be more robust to different settings of iid/non-iid degrees compared to the original paper.

# %% [markdown]
# **Citations:**
#
# - [Improving Local Training in Federated Learning via Temperature Scaling – Lee, Kim, and Ko](https://arxiv.org/pdf/2401.09986v2)
#
# - [Distilling the Knowledge in a Neural Network – Hinton et al.](https://arxiv.org/pdf/1503.02531)
#
# - [LTD: Low Temperature Distillation for Robust Adversarial Training – Chen et al.](https://arxiv.org/pdf/2111.02331)
#
# - [FedBalancer: Data and Pace Control for Efficient Federated Learning on Heterogeneous Clients – Shin et al.](https://arxiv.org/abs/2201.01601)
#
# - We used some recent surveys from 2024-25 pertaining to FedKD as well to do our research

# %% [markdown]
# ---
